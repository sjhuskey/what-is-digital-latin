# %%
# Heavily cribbed from https://towardsdatascience.com/topic-modeling-and-latent-dirichlet-allocation-in-python-9bf156893c24
# and https://towardsdatascience.com/topic-modelling-in-python-with-nltk-and-gensim-4ef03213cd21

# Import necessary items from the Classical Languages Toolkit and elsewhere for cleaning the data.
import gensim
from cltk.tokenize.word import nltk_tokenize_words
from cltk.tokenize.sentence import TokenizeSentence
tokenizer = TokenizeSentence('latin')
from cltk.stop.latin import CorpusStoplist
from cltk.stop.latin import STOPS_LIST
from cltk.stem.lemma import LemmaReplacer
from cltk.stem.latin.j_v import JVReplacer

jv_replacer = JVReplacer()
tokenizer = TokenizeSentence('latin')
lemmatizer = LemmaReplacer('latin')

# %%
# A function to prepare the raw text and turn it into tokens.

def prepare_text(text):
    # tokenize the individual words
    tokens = nltk_tokenize_words(text)
    # remove any tokens smaller than 4 characters in length
    tokens = [token for token in tokens if len(token) > 4]
    # replace j and v with i and u.
    tokens = [jv_replacer.replace(token) for token in tokens]
    # make all words lower-case
    tokens = [token.lower() for token in tokens]
    # remove punctuation
    tokens = [token for token in tokens if token not in ['.', ',','!','?','"',':', ';','[',']']]
    # remove line numbers
    tokens = [x for x in tokens if not (x.isdigit() or x[0] == '-' and x[1:].isdigit())]
    # turn all of the tokens into their dictionary forms
    tokens = [''.join(lemmatizer.lemmatize(token)) for token in tokens]
    # remove common words
    tokens = [token for token in tokens if token not in STOPS_LIST]
    return tokens

# %%
# We know from experience that the data include certain words that are generic, so we remove them here.
add_stops = ['noster','nos','ille','quoque','primus']
for stop in add_stops:
    STOPS_LIST.append(stop)

# %%
# Open the text files and process them.
import random
import os, glob
text_data = []
folder_path = '/home/sjhuskey/Dropbox/What-is-digital-latin/texts'
for filename in glob.glob(os.path.join(folder_path, '*.txt')):
    with open(filename, 'r') as f:
        text = f.read()
        tokens = prepare_text(text)
        if random.random() > .8: # What does this do?
            text_data.append(tokens)

# %%
text_data
# Out:
# [['fortis',
#   'mico',
#   'seni',
#   'canthus1',
#   'miconis',
#   'alumnus',
#   'torreo',
#   'patulus',
#   'vito',
#   'ilex',
#   'solo1',
#   'juvenis',
#   'seni',
#   'praecipio',
#   'do',
#   'alumnus',
#   'talis',
#   'verbum',
#   'refero',
#   'tremulus',
#   'titubo',
#   'labrum1',
#   'erro1',
#   'video',
#   'dumetum',
#   'capella1',
#   'canus',
#   'lascivus',
#   'concaedes',
#   'gramen',
#   'mordeo',
#   'canthus1',
#   'grex',
#   'mons',
#   'removeo',
#   'cerno',
#   'apricus',
#   'decerpo',
#   'gramen',
#   'campus1',
#   'seni',
#   'juvenis',
#   'pater',
#   'tueor',
#   'accipio',
#   'certus',
#   'insudo',
#   'labor2',
#   'gnauam',
#   'exerceo',
#   'juventa',
#   'ad-specio',
#   'aetas',
#   'mille',
#   'querela',
#   'affero',
#   'baculus',
#   'premo',
#   'inclino',
#   'senectus2',
#   'rego',
#   'amo',
#   'lustro1',
#   'capella1',
#   'bonus',
#   'pratum',
#   'erro1',
#   'mollis',
#   'agna1',
#   'percipio',
#   'tinnio',
#   'volucris',
#   'incipio',
#   'nidus',
#   'revorto',
#   'luto1',
#   'hirundo',
#   'protinus',
#   'hiberno',
#   'pecus2',
#   'mouebis',
#   'ovile',
#   'etenim',
#   'bonus',
#   'uernanti',
#   'germen',
#   'silva',
#   'pullo',
#   'aestivus',
#   'reparabilis',
#   'incoho',
#   'umbro',
#   'floreo',
#   'saltus1',
#   'viridis',
#   'renascor',
#   'annus',
#   'venus2',
#   'calidus',
#   'scintillo',
#   'fervo',
#   'amor',
#   'lasciuumque',
#   'pecus2',
#   'salio1',
#   'accipio',
#   'hircos',
#   'grex',
#   'pascuum',
#   'mitto',
#   'recludo',
#   'sum1',
#   'placo',
#   'palo',
#   'caespes',
#   'focus',
#   'genius',
#   'faunumque',
#   'lar',
#   'salio1',
#   'far',
#   'tepidus',
#   'hostia',
#   'culter',
#   'imbuo',
#   'vivo',
#   'ovile',
#   'lustro1',
#   'campus1',
#   'ovis',
#   'dumetum',
#   'capella1',
#   'do',
#   'simul',
#   'transcendo',
#   'mons',
#   'coepio',
#   'spatium',
#   'tepefacio',
#   'hora1',
#   'fortis',
#   'vaco',
#   'matutinus',
#   'relaxo',
#   'frigus',
#   'tumidus',
#   'spumo',
#   'mulctra',
#   'papilla',
#   'impleo',
#   'fluo',
#   'rursus',
#   'premo',
#   'occiduus',
#   'mulceo',
#   'redigo',
#   'hora1',
#   'parco',
#   'for',
#   'compendium',
#   'tantus',
#   'destruo',
#   'niveus',
#   'venalis',
#   'cascus',
#   'agnus',
#   'praecipuus',
#   'fetura',
#   'colo1',
#   'amor',
#   'pudeo',
#   'serus',
#   'ovile',
#   'viso',
#   'jaceo',
#   'pario2',
#   'resolvo',
#   'recens',
#   'umeo',
#   'porto',
#   'nascor',
#   'tepeo',
#   'fero',
#   'tremulus',
#   'nondum',
#   'sto',
#   'paro1',
#   'longinquus',
#   'procul',
#   'praesaepe',
#   'herba',
#   'nimis',
#   'amoveo',
#   'sector2',
#   'pabulum',
#   'silva',
#   'perago',
#   'vernus',
#   'io1',
#   'inconstantia',
#   'tempus',
#   'verus',
#   'dubito',
#   'fido',
#   'frons2',
#   'serenus1',
#   'blandus',
#   'arrideo',
#   'caligo1',
#   'nimbus',
#   'infero',
#   'mitto',
#   'torreo',
#   'aufero',
#   'agna1',
#   'longus',
#   'sitio',
#   'affero',
#   'aestus',
#   'sum1',
#   'vario',
#   'mutabilis',
#   'caelum1',
#   'silva',
#   'committo',
#   'grex',
#   'longus',
#   'herba',
#   'quaero',
#   'pecus2',
#   'exeo',
#   'umidus',
#   'dulcis',
#   'efficio',
#   'cibus',
#   'quotiens',
#   'fugio',
#   'eurus',
#   'frigidum',
#   'nocturnus',
#   'tango',
#   'pascuum',
#   'matutinus',
#   'luceo',
#   'gramen',
#   'gutta1',
#   'simul',
#   'arguo',
#   'no1',
#   'increpo',
#   'cicada',
#   'fons',
#   'compello1',
#   'grex',
#   'protinus',
#   'herba',
#   'campus1',
#   'permitto',
#   'sequor',
#   'protego',
#   'interea',
#   'vetus',
#   'porrigo1',
#   'aesculus',
#   'umbro',
#   'verus',
#   'declinis',
#   'tepesco',
#   'incipio',
#   'sera',
#   'video',
#   'mereo',
#   'rursus',
#   'pasco',
#   'grex',
#   'opacus',
#   'desero2',
#   'lucus1',
#   'prior',
#   'aestivus',
#   'pecus2',
#   'includo',
#   'ovile',
#   'levis1',
#   'nidus',
#   'somnus',
#   'capto',
#   'volucris',
#   'cogito',
#   'tremulus',
#   'queribundus',
#   'fritinnio',
#   'tempus',
#   'maturo',
#   'demo',
#   'lana',
#   'sucidus',
#   'teres',
#   'constringo',
#   'vellus',
#   'juncus',
#   'hircorumque',
#   'juba1',
#   'oleo1',
#   'caedo',
#   'barba1',
#   'secerno',
#   'pecus2',
#   'grex',
#   'noto',
#   'consimilis',
#   'includo',
#   'como1',
#   'longus',
#   'minuo',
#   'molle',
#   'durus',
#   'coeo',
#   'candidus',
#   'fuscus1',
#   'uacuas',
#   'pono',
#   'velamen',
#   'costa',
#   'denudo',
#   'circumspicio',
#   'acuo',
#   'forpex',
#   'laedo',
#   'cutis',
#   'taceo',
#   'pustula',
#   'virus',
#   'tego',
#   'occulto2',
#   'vulnus',
#   'ferrum',
#   'rumpo',
#   'miser',
#   'fragilis',
#   'robigo',
#   'corpus',
#   'arrodo',
#   'sanies',
#   'putria',
#   'contraho',
#   'providus',
#   'moneo',
#   'uiuentia',
#   'sulphura',
#   'scilla',
#   'caput',
#   'virosus1',
#   'bitumen',
#   'porto',
#   'vulnus',
#   'fero',
#   'bruttia',
#   'desum',
#   'liquidus',
#   'picus1',
#   'unguis',
#   'tergum',
#   'memento',
#   'lineo',
#   'pondero',
#   'mel',
#   'argentum',
#   'coquo',
#   'lentus',
#   'bitumen',
#   'aenus3',
#   'imprimo',
#   'nomino',
#   'lito',
#   'aufero',
#   'ingens',
#   'lego2',
#   'possessor',
#   'siccus',
#   'fervidus',
#   'tellus',
#   'rimosus',
#   'palus2',
#   'multus',
#   'torridus',
#   'aestuo',
#   'fragilis',
#   'nimius',
#   'puluerat',
#   'herba',
#   'luridus',
#   'convenio',
#   'succendo',
#   'galbanum',
#   'saeptum',
#   'ceruino',
#   'lustro1',
#   'mapalia',
#   'obsum',
#   'malo',
#   'anguis',
#   'video',
#   'serpens',
#   'cado',
#   'mino',
#   'stringo',
#   'dens',
#   'uncus1',
#   'inanis',
#   'debilis',
#   'marceo',
#   'obtundo',
#   'jaceo',
#   'exarmo',
#   'veneno',
#   'vicina',
#   'circumspicio',
#   'tempus',
#   'bruma',
#   'ratio',
#   'gero1',
#   'aperio',
#   'vinea',
#   'saepes',
#   'porto',
#   'lego2',
#   'securus',
#   'circito',
#   'incipio',
#   'falx',
#   'no1',
#   'vivo',
#   'recido1',
#   'frondeo',
#   'tener',
#   'summatim',
#   'stringo',
#   'virga',
#   'hiems',
#   'servo',
#   'como1',
#   'permaneo',
#   'vireo1',
#   'tremulus',
#   'excutio',
#   'africus',
#   'umbro',
#   'convenio',
#   'tepidus',
#   'fenilibus',
#   'promo',
#   'pecus2',
#   'extremus',
#   'claudo1',
#   'annus',
#   'niteo',
#   'labo',
#   'tempus',
#   'gnauaque',
#   'sedulitas',
#   'redeo',
#   'pastorius',
#   'virtus',
#   'pigeo',
#   'ramus',
#   'siccus',
#   'misceo',
#   'recens',
#   'sucus',
#   'adhibeo',
#   'novi',
#   'torridus',
#   'nimbus',
#   'insto',
#   'hiems',
#   'nimius',
#   'nix',
#   'cogo',
#   'incurso',
#   'veto',
#   'no1',
#   'constringo',
#   'frondeo',
#   'levo1',
#   'hedera',
#   'molle',
#   'salictum',
#   'valles',
#   'premo',
#   'medius',
#   'sum1',
#   'penso',
#   'tuus',
#   'canthus1',
#   'grex',
#   'virido',
#   'nihil',
#   'aridus',
#   'ingens',
#   'pono',
#   'quivis',
#   'struo',
#   'prosum',
#   'acervus',
#   'virgeus',
#   'desum',
#   'liquidus',
#   'turgentia',
#   'qui1',
#   'plenus',
#   'vitalis',
#   'medulla',
#   'praecipuus',
#   'gelidus',
#   'stipulo',
#   'frondeo',
#   'caducus',
#   'sterno',
#   'solus1',
#   'fortis',
#   'rigo',
#   'penetrabilis',
#   'corpus',
#   'internus',
#   'uastet',
#   'pecuaria',
#   'morbus',
#   'multus',
#   'memini',
#   'volo1',
#   'multus',
#   'supersum',
#   'cado',
#   'fugo',
#   'frigidus',
#   'aestivus',
#   'impello',
#   'noctifer',
#   'hora1'],
#  ['carmen1',
#   'bonus',
#   'venio',
#   'cano',
#   'extremus',
#   'arethusa',
#   'concedo',
#   'laboro',
#   'paucus',
#   'gallus1',
#   'lego2',
#   'lycoris',
#   'carmen1',
#   'dico2',
#   'nego',
#   'carmen1',
#   'gallus1',
#   'fluctus',
#   'subterlabere',
#   'sicanos',
#   'doron',
#   'amarus',
#   'intermisceo',
#   'unda',
#   'incipio',
#   'sollicitus',
#   'gallus1',
#   'dico2',
#   'amor',
#   'tener',
#   'attondeo',
#   'sima',
#   'virgultus',
#   'capella1',
#   'cano',
#   'surdus',
#   'respondeo',
#   'omne',
#   'silva',
#   'nemus',
#   'saltus1',
#   'habeo',
#   'puella',
#   'naides',
#   'indignus',
#   'gallus1',
#   'amor',
#   'pereo',
#   'parnasi',
#   'pindi',
#   'mora',
#   'facio',
#   'aonie',
#   'aganippe',
#   'laurus',
#   'fleo',
#   'myrica',
#   'pinifer',
#   'jaceo',
#   'maenalus',
#   'gelidus',
#   'fleo',
#   'lycaei',
#   'sto',
#   'circos',
#   'paeniteo',
#   'paeniteo',
#   'pecus1',
#   'divus',
#   'poeta',
#   'formosus',
#   'flumen',
#   'pasco',
#   'adonis',
#   'venio',
#   'opilio',
#   'tardus',
#   'venio',
#   'subulcus',
#   'uuidus',
#   'hiberno',
#   'venio',
#   'glande',
#   'menalcas',
#   'omnes',
#   'rogo',
#   'venio',
#   'apollo',
#   'gallus1',
#   'insanio',
#   'inquam',
#   'lycoris',
#   'nix',
#   'alius2',
#   'horridus',
#   'castro',
#   'sequor',
#   'venio',
#   'agrestis',
#   'capio',
#   'siluanus',
#   'honor',
#   'floreo',
#   'ferula',
#   'grandis',
#   'lilium',
#   'quasso',
#   'arcadiae',
#   'venio',
#   'video',
#   'sanguineus',
#   'ebulus',
#   'baca',
#   'minius1',
#   'rubeo',
#   'ecquis',
#   'modus',
#   'inquam',
#   'talis',
#   'curo',
#   'lacrima',
#   'crudelis',
#   'gramen',
#   'rivus',
#   'cytisus',
#   'saturo',
#   'frondeo',
#   'capella1',
#   'tero',
#   'canto',
#   'arcades',
#   'inquam',
#   'mons',
#   'vester',
#   'canto',
#   'pereo',
#   'arcades',
#   'mollis',
#   'quiesco',
#   'vester',
#   'fistula',
#   'dico2',
#   'amor',
#   'utinam',
#   'vester',
#   'sum1',
#   'custos',
#   'grex',
#   'maturus',
#   'vinitor',
#   'certus',
#   'phyllon',
#   'edo1',
#   'amyntas',
#   'furo',
#   'fuscus1',
#   'amyntas',
#   'niger',
#   'viola',
#   'vaccinium',
#   'niger',
#   'salix',
#   'lentus',
#   'jaceo',
#   'sero2',
#   'phyllon',
#   'lego2',
#   'canto',
#   'amyntas',
#   'gelidus',
#   'fons',
#   'molle',
#   'pratum',
#   'lycori',
#   'no1',
#   'consumo',
#   'insanus1',
#   'martes',
#   'armus',
#   'medius',
#   'adverro',
#   'detineo',
#   'hostis',
#   'procul',
#   'patrium',
#   'credo',
#   'tantus',
#   'alpinas',
#   'nix',
#   'frigus',
#   'rheni',
#   'video',
#   'frigus',
#   'laedo',
#   'tener',
#   'glacio',
#   'seco',
#   'asper1',
#   'planto',
#   'chalcidico',
#   'condio',
#   'verro',
#   'carmen1',
#   'pastor',
#   'siculi',
#   'modulor',
#   'avena',
#   'certus',
#   'silva',
#   'spelaeum',
#   'fera',
#   'malo',
#   'teneo',
#   'incido1',
#   'amor',
#   'arbor1',
#   'cresco',
#   'cresco',
#   'amor',
#   'interea',
#   'misceo',
#   'lustro1',
#   'maenala',
#   'nympha',
#   'acer',
#   'venor',
#   'aper1',
#   'veto',
#   'frigus',
#   'parthenios',
#   'canis1',
#   'circumdo',
#   'saltus1',
#   'rupes',
#   'video',
#   'lucus1',
#   'sono',
#   'libo1',
#   'partho',
#   'torqueo',
#   'cydonia',
#   'cornus1',
#   'spiculum',
#   'tamquam',
#   'medicina',
#   'furor2',
#   'malo',
#   'homo',
#   'mitesco',
#   'disco',
#   'hamadryades',
#   'rursus',
#   'carmen1',
#   'placo',
#   'rursus',
#   'concedo',
#   'silva',
#   'muto1',
#   'laboro',
#   'frigus',
#   'medius',
#   'hebrumque',
#   'bibo1',
#   'sithoniasque',
#   'nix',
#   'hiems',
#   'subeo',
#   'aquosus',
#   'morior',
#   'libo1',
#   'aethiopum',
#   'verso',
#   'sido',
#   'cancer',
#   'omne',
#   'vincio',
#   'cedo1',
#   'amor',
#   'diva',
#   'vester',
#   'cano',
#   'poeta',
#   'sedeo',
#   'gracilis',
#   'fiscella',
#   'tego',
#   'hibiscum',
#   'pierides',
#   'facio',
#   'magnus',
#   'gallus1',
#   'gallus1',
#   'qui1',
#   'tantus',
#   'cresco',
#   'hora1',
#   'quantus',
#   'viridis',
#   'subicio',
#   'alnus',
#   'surgo',
#   'solo1',
#   'gravis',
#   'canto',
#   'umbro',
#   'juniperus',
#   'gravis',
#   'umbro',
#   'noceo',
#   'frugis',
#   'umbra',
#   'domus',
#   'sero1',
#   'venio',
#   'hesperus',
#   'capella1'],
#  ['syracosio',
#   'digno',
#   'ludo',
#   'verro',
#   'erubesco',
#   'silva',
#   'habito',
#   'thalia',
#   'caneo',
#   'rego',
#   'proelio',
#   'cynthius',
#   'auro',
#   'vello',
#   'admoneo',
#   'pastor',
#   'tityre',
#   'pinguis',
#   'pasco',
#   'oportet',
#   'deduco',
#   'dico2',
#   'carmen1',
#   'supo',
#   'sum1',
#   'dico2',
#   'laudo',
#   'cupio',
#   'triste',
#   'condo',
#   'bellus',
#   'agrestis',
#   'teneo',
#   'meditor',
#   'harundo',
#   'musam',
#   'injussus1',
#   'capio',
#   'amor',
#   'lego2',
#   'myrica',
#   'no1',
#   'cano',
#   'phoebo',
#   'gratus',
#   'praescribo',
#   'pagina',
#   'nomen',
#   'pergo',
#   'pierides',
#   'chromis',
#   'mnasylus',
#   'antrum',
#   'silenum',
#   'puer',
#   'somnus',
#   'video',
#   'jaceo',
#   'inflo',
#   'hesternus',
#   'vena',
#   'semper',
#   'iaccho',
#   'sero2',
#   'procul',
#   'tantus',
#   'caput',
#   'delabor',
#   'jaceo',
#   'gravis',
#   'attero',
#   'pendeo',
#   'cantharus',
#   'aggredior',
#   'saepis',
#   'senex',
#   'carmen1',
#   'ludo',
#   'inicio',
#   'vinculum',
#   'sero2',
#   'addo',
#   'socia',
#   'timidus',
#   'supervenio',
#   'aegle',
#   'aegle',
#   'naiadum',
#   'pulcher1',
#   'jam',
#   'video',
#   'sanguineus',
#   'frons2',
#   'morior',
#   'tempus',
#   'pingo',
#   'dolus',
#   'rideo',
#   'vinculum',
#   'necto',
#   'inquam',
#   'solvo',
#   'puer',
#   'sero1',
#   'video',
#   'carmen1',
#   'volo1',
#   'cognosco',
#   'carmen1',
#   'alius2',
#   'merces1',
#   'simul',
#   'incipio',
#   'numerus',
#   'faunosque',
#   'fero',
#   'video',
#   'ludo',
#   'rigida',
#   'moto',
#   'cacumen',
#   'quercus',
#   'tantus',
#   'phoebo',
#   'gaudeo',
#   'parnasia',
#   'rupes',
#   'tantus',
#   'rhodope',
#   'miro',
#   'ismarus',
#   'orphea',
#   'caneo',
#   'magnus',
#   'inane',
#   'cogo',
#   'semino',
#   'terra',
#   'animaequus',
#   'mare',
#   'sum1',
#   'liquidus',
#   'simul',
#   'ignis',
#   'exordium',
#   'omne',
#   'tener',
#   'mundus',
#   'con-cerno',
#   'orbus',
#   'duro',
#   'solus1',
#   'discludo',
#   'nerea',
#   'pontus1',
#   'coepio',
#   'res',
#   'paulatim',
#   'sumo',
#   'formo',
#   'jam',
#   'novus',
#   'terra',
#   'stupeo',
#   'lucesco',
#   'solo1',
#   'alo',
#   'cado',
#   'sub-moveo',
#   'nubis',
#   'imber',
#   'incipio',
#   'silva',
#   'surgo',
#   'cumque',
#   'ignarus',
#   'erro1',
#   'animalis',
#   'mons',
#   'lapido',
#   'pyrrhae',
#   'jacio',
#   'saturnia',
#   'regno',
#   'caucasiasque',
#   'refero',
#   'volucris',
#   'furtum',
#   'promethei',
#   'adjungo',
#   'hyle',
#   'nauta',
#   'fons',
#   'relinquo',
#   'clamo',
#   'litus3',
#   'sono',
#   'fortuno',
#   'numquam',
#   'armentum',
#   'sum1',
#   'pasiphaen',
#   'niveus',
#   'solo1',
#   'amor',
#   'juvencus',
#   'virgo',
#   'infelix',
#   'demo',
#   'capio',
#   'proetides',
#   'impleo',
#   'fallo',
#   'mugitus',
#   'ager',
#   'turpis',
#   'pecus2',
#   'sequor',
#   'concubo',
#   'quivis',
#   'collus',
#   'timeo',
#   'arater',
#   'saepis',
#   'quaero',
#   'cornu',
#   'frons2',
#   'virgo',
#   'infelix',
#   'mons',
#   'erro1',
#   'fero',
#   'niveus',
#   'mollio',
#   'fulcio',
#   'hyacinthus',
#   'ilex',
#   'niger',
#   'palleo',
#   'rumino',
#   'herba',
#   'magnus',
#   'sequor',
#   'grex',
#   'claudo',
#   'nympha',
#   'dictaeae',
#   'nympha',
#   'nemus',
#   'claudo',
#   'saltus1',
#   'fortis',
#   'fero',
#   'oculus',
#   'obvius',
#   'errabundus',
#   'bos',
#   'vestigium',
#   'forsitan',
#   'herba',
#   'capio',
#   'viridis',
#   'armentum',
#   'sequor',
#   'perduco',
#   'stabulo',
#   'cortynia',
#   'vacca1',
#   'cano',
#   'hesperidum',
#   'miro',
#   'puella',
#   'phaethontiadas',
#   'muscus',
#   'circundat',
#   'amarus',
#   'cortex',
#   'procerus',
#   'erigo',
#   'alnus',
#   'cano',
#   'erro1',
#   'per-meto2',
#   'flumen',
#   'gallus1',
#   'aonas',
#   'mons',
#   'duco',
#   'soror',
#   'phoebi',
#   'chorus',
#   'assurgo',
#   'omne',
#   'linus',
#   'divino',
#   'carmen1',
#   'pastor',
#   'flos',
#   'crinio',
#   'orno',
#   'amarus',
#   'dico2',
#   'calamus',
#   'accipio',
#   'musae',
#   'ascraeo',
#   'qui1',
#   'soleo',
#   'canto',
#   'rigida',
#   'deduco',
#   'mons',
#   'ornus',
#   'grynei',
#   'nemus',
#   'dico2',
#   'origo1',
#   'lucus1',
#   'jacto',
#   'apollo',
#   'loquor',
#   'scyllam',
#   'sequor',
#   'candidus',
#   'succingo',
#   'latro1',
#   'inguina',
#   'monstrum',
#   'dulichias',
#   'vexo',
#   'ratis',
#   'gurges1',
#   'timidus',
#   'nauta',
#   'canis1',
#   'lacero',
#   'marinus',
#   'muto1',
#   'terei',
#   'narro',
#   'artus1',
#   'philomela',
#   'daps',
#   'paro1',
#   'curro',
#   'desero2',
#   'peto',
#   'qui1',
#   'infelix',
#   'tego',
#   'supo',
#   'volito',
#   'omne',
#   'phoebo',
#   'quondam',
#   'meditor',
#   'beatus',
#   'audio',
#   'eurotas',
#   'jubeo',
#   'edisco',
#   'laurus',
#   'cano',
#   'pello',
#   'refero',
#   'sidus',
#   'vallo',
#   'cogo',
#   'donec',
#   'stabulum',
#   'numerus',
#   'refero',
#   'jubeo',
#   'invito',
#   'procedo',
#   'uesper',
#   'olympo'],
#  ['damoeta',
#   'cujus',
#   'pecus2',
#   'meliboei',
#   'verus',
#   'aegonos',
#   'nuper',
#   'trado',
#   'aegon',
#   'infelix',
#   'semper',
#   'pecus2',
#   'neaeram',
#   'foveo',
#   'praefero',
#   'vereor',
#   'alienus',
#   'custos',
#   'mulgeo',
#   'sucus',
#   'pecus1',
#   'subduco',
#   'agnus',
#   'parcus',
#   'vis',
#   'obicio',
#   'memento',
#   'nosco',
#   'transverto',
#   'tueor',
#   'hircis',
#   'quo—sed',
#   'facilis',
#   'nympha',
#   'risere—sacello',
#   'credo',
#   'arbustus',
#   'video',
#   'miconos',
#   'vita',
#   'incido1',
#   'falx',
#   'novella',
#   'vetus',
#   'fagus',
#   'daphnidos',
#   'arx',
#   'frango',
#   'calamus',
#   'perverto',
#   'menalca',
#   'video',
#   'puer',
#   'dono',
#   'doleo',
#   'noceo',
#   'morior',
#   'edo1',
#   'dominus',
#   'facio',
#   'audeo',
#   'talis',
#   'furo',
#   'damonos',
#   'malus',
#   'caper',
#   'excipio',
#   'insidiae',
#   'multus',
#   'latro1',
#   'lycisca',
#   'clamo',
#   'proripio',
#   'tityre',
#   'pecus2',
#   'carectum',
#   'lateo',
#   'canto',
#   'vinco',
#   'reddo',
#   'carmen1',
#   'mereo',
#   'fistula',
#   'caper',
#   'nescio',
#   'caper',
#   'damon',
#   'fateor',
#   'reddo',
#   'nego',
#   'canto',
#   'umquam',
#   'fistula',
#   'jungo',
#   'trivius',
#   'indoctus',
#   'soleo',
#   'strideo',
#   'miser',
#   'stipulo',
#   'disperdo',
#   'carmen1',
#   'uter',
#   'vicissim',
#   'experior',
#   'uitulam—ne',
#   'fortis',
#   'recuso',
#   'venio',
#   'mulctra',
#   'bini',
#   'uber1',
#   'fetus—',
#   'depono',
#   'pignus',
#   'certo2',
#   'grex',
#   'audeo',
#   'depono',
#   'pater',
#   'injustus',
#   'noverca',
#   'bis',
#   'numero1',
#   'pecus2',
#   'alter',
#   'haedus',
#   'verus',
#   'multus',
#   'fateor',
#   'magnus',
#   'insanio',
#   'libo1',
#   'poculum',
#   'pono',
#   'faginus',
#   'caelo',
#   'divinus',
#   'alcimedontos',
#   'lentus',
#   'qui1',
#   'torno',
#   'facilis',
#   'superaddo',
#   'vita',
#   'diffundo',
#   'hedera',
#   'vestio',
#   'palleo',
#   'corymbus',
#   'medius',
#   'signo',
#   'conus',
#   'et—quis',
#   'alter',
#   'describo',
#   'radio',
#   'totus1',
#   'gens',
#   'orbo',
#   'tempus',
#   'messor',
#   'curvus',
#   'arator',
#   'habeo',
#   'necdum',
#   'labrum1',
#   'admoveo',
#   'condio',
#   'servo',
#   'alcimedon',
#   'poculum',
#   'facio',
#   'mollio',
#   'circos',
#   'ansa',
#   'amplector',
#   'acanthus',
#   'orpheaque',
#   'medius',
#   'pono',
#   'silva',
#   'sequor',
#   'necdum',
#   'labrum1',
#   'admoveo',
#   'condio',
#   'servo',
#   'vitula',
#   'specto',
#   'nihil',
#   'poculum',
#   'laudo',
#   'numquam',
#   'hodie',
#   'effugio',
#   'venio',
#   'voco',
#   'audio',
#   'tantus',
#   'venio',
#   'palaemon',
#   'efficio',
#   'posthac',
#   'lacesso',
#   'habeo',
#   'fugio',
#   'tantus',
#   'vinco',
#   'palaemon',
#   'sensus2',
#   'imis—res',
#   'parua—reponas',
#   'dico2',
#   'quandoquidem',
#   'mollio',
#   'consido',
#   'herba',
#   'omne',
#   'omne',
#   'parturio',
#   'arbos',
#   'frondeo',
#   'silva',
#   'formosus',
#   'annus',
#   'incipio',
#   'damoeta',
#   'sequor',
#   'menalca',
#   'alternus',
#   'dico2',
#   'amo',
#   'alterno',
#   'camenae',
#   'principium',
#   'musae',
#   'io1',
#   'omne',
#   'plenus',
#   'colo1',
#   'terra',
#   'carmen1',
#   'cura',
#   'phoebus',
#   'phoebo',
#   'semper',
#   'munero',
#   'laurus',
#   'suavis',
#   'rubeo',
#   'hyacinthus',
#   'galatea',
#   'peto',
#   'lascivus',
#   'puella',
#   'fugio',
#   'salix',
#   'cupio',
#   'video',
#   'offertor',
#   'ulter',
#   'ignis',
#   'amyntas',
#   'nosco',
#   'canis1',
#   'de_-lio',
#   'pario2',
#   'ueneri',
#   'munero',
#   'noto',
#   'locus',
#   'aerius',
#   'congero1',
#   'palumbis',
#   'puer',
#   'siluestri',
#   'arbor1',
#   'lego2',
#   'aureus',
#   'decem',
#   'alter',
#   'mitto',
#   'quotiens',
#   'galatea',
#   'loquor',
#   'pars',
#   'venio',
#   'divus',
#   'refero',
#   'aurum',
#   'prodo',
#   'animo',
#   'sperno',
#   'amynta',
#   'sector2',
#   'aper1',
#   'rete',
#   'servo',
#   'phyllida',
#   'mitto',
#   'natalis1',
#   'iolla',
#   'facio',
#   'vitula',
#   'frugis',
#   'venio',
#   'phyllida',
#   'alius2',
#   'discedo',
#   'fleo',
#   'longus',
#   "'formose",
#   'inquam',
#   'iolla',
#   'triste',
#   'lupus1',
#   'stabulum',
#   'maturus',
#   'frugis',
#   'imber',
#   'arbor1',
#   'venio',
#   'amaryllidos',
#   'dulcis',
#   'sero1',
#   'depello',
#   'arbutus',
#   'haedus',
#   'lentus',
#   'salix',
#   'pecus1',
#   'solus',
#   'amyntas',
#   'pollio',
#   'quivis',
#   'rusticus',
#   'musam',
#   'pierides',
#   'vitula',
#   'lector',
#   'pasco',
#   'vester',
#   'pollio',
#   'facio',
#   'carmen1',
#   'pasco',
#   'taurus1',
#   'cornus1',
#   'peto',
#   'pes',
#   'spargo1',
#   'harena',
#   'pollio',
#   'venio',
#   'gaudeo',
#   'mel',
#   'fluo',
#   'fero',
#   'rubus',
#   'asper1',
#   'amomum',
#   'bauium',
#   'carmen1',
#   'jungo',
#   'vulpis',
#   'mulgeo',
#   'hircos',
#   'lego2',
#   'floreo',
#   'nasco',
#   'fraga',
#   'frigidus—o',
#   'puer',
#   'fugio',
#   'hinc—latet',
#   'anguis',
#   'herba',
#   'parco',
#   'nimius',
#   'procedo',
#   'ripa',
#   'credo',
#   'aries',
#   'vellus',
#   'sicco',
#   'tityre',
#   'pasco',
#   'flumen',
#   'reicio',
#   'capella1',
#   'tempus',
#   'omne',
#   'fons',
#   'lavo',
#   'cogo',
#   'puer',
#   'praecipio',
#   'aestus',
#   'nuper',
#   'frustro',
#   'presso',
#   'uber1',
#   'palma1',
#   'pinguis',
#   'macer',
#   'taurus1',
#   'exitium',
#   'pecus1',
#   'pecus1',
#   'magistro',
#   'certe—neque',
#   'causa',
#   'est—uix',
#   'os2',
#   'haereo',
#   'nescio',
#   'tener',
#   'oculus',
#   'fascino',
#   'agnus',
#   'qui1',
#   'terris—et',
#   'magnus',
#   'apollo—',
#   'pateo',
#   'caelum1',
#   'spatium',
#   'amplus',
#   'ulna',
#   'qui1',
#   'terra',
#   'inscribo',
#   'nomino',
#   'rex',
#   'nasco',
#   'floreo',
#   'phyllida',
#   'solus',
#   'habeo',
#   'tantus',
#   'compono',
#   'lito',
#   'vitula',
#   'dignus',
#   'amor',
#   'metuo',
#   'dulcis',
#   'experior',
#   'amarus',
#   'claudo',
#   'rivus',
#   'puer',
#   'pratum',
#   'bibo1'],
#  ['fiscella',
#   'fluvialis',
#   'tityre',
#   'juncus',
#   'texitur',
#   'raucus',
#   'immunis',
#   'cicada',
#   'incipio',
#   'habeo',
#   'gracilis',
#   'harundo',
#   'carmen1',
#   'compono',
#   'calamus',
#   'inflo',
#   'labellum1',
#   'doceo',
#   'uersuque',
#   'bonus',
#   'faveo',
#   'apollo',
#   'incipio',
#   'salix',
#   'haedus',
#   'gramen',
#   'vacca1',
#   'detondent',
#   'viridis',
#   'grex',
#   'permitto',
#   'campus1',
#   'suadeo',
#   'clemens1',
#   'solus1',
#   'annus',
#   'cano',
#   'como1',
#   'vinco',
#   'thymoeta',
#   'juvenis',
#   'carus1',
#   'carmen1',
#   'cogo',
#   'dico2',
#   'calamus',
#   'verro',
#   'cantauimus',
#   'securus',
#   'hilaris',
#   'aetas',
#   'ludo',
#   'amor',
#   'album',
#   'caput',
#   'ueneres',
#   'tepesco',
#   'annus',
#   'ruricola',
#   'dependo',
#   'fistula',
#   'fauno',
#   'sono',
#   'nuper',
#   'carmen1',
#   'victor1',
#   'rideo',
#   'calamus',
#   'dissonus',
#   'flamen2',
#   'mopsi',
#   'judex',
#   'seni',
#   'meliboeus',
#   'uter',
#   'audio',
#   'laudo',
#   'sublimus',
#   'fero',
#   'emereo',
#   'permetior',
#   'tempus',
#   'vita',
#   'secerno',
#   'orbus',
#   'habeo',
#   'mundus',
#   'pius',
#   'meliboei',
#   'gratia',
#   'vivo',
#   'dico2',
#   'honoro',
#   'praedulcis',
#   'tibia',
#   'maneo',
#   'paro1',
#   'decet',
#   'jubeo',
#   'gratus',
#   'jubeo',
#   'dignus',
#   'seni',
#   'carmen1',
#   'phoebus',
#   'calamus',
#   'fides1',
#   'linus',
#   'oeagrius',
#   'orpheus',
#   'concino',
#   'tot',
#   'laudo',
#   'sono',
#   'laudo',
#   'deposco',
#   'avena',
#   'accipio',
#   'supo',
#   'cerasus1',
#   'cerno',
#   'amnis',
#   'contineo',
#   'incido2',
#   'servo',
#   'carmen1',
#   'libro',
#   'venio',
#   'garrulus',
#   'pinus',
#   'obstrepo',
#   'ulmus',
#   'potis',
#   'fagosque',
#   'peto',
#   'canto',
#   'libo1',
#   'viridis',
#   'subicio',
#   'herba',
#   'mollio',
#   'fero',
#   'taceo',
#   'no1',
#   'quiesco',
#   'aspicio',
#   'procul',
#   'decerpo',
#   'gramen',
#   'taurus1',
#   'omniparens',
#   'aether',
#   'res',
#   'causa',
#   'liquor2',
#   'corpus',
#   'genetrix',
#   'tellus',
#   'vitalis',
#   'accipio',
#   'cano',
#   'meliboeo',
#   'mitto',
#   'sentio',
#   'do',
#   'quiesco',
#   'sublimo',
#   'anima',
#   'caelestia',
#   'templum',
#   'sidereasque',
#   'colo1',
#   'sedeo',
#   'mundo',
#   'fruor',
#   'adverto',
#   'modus',
#   'benignus',
#   'pectus',
#   'foveo',
#   'meliboee',
#   'probo',
#   'longus',
#   'cunctus',
#   'specto',
#   'senectus2',
#   'felix1',
#   'novus',
#   'circulus',
#   'innocuus',
#   'claudo1',
#   'tempus',
#   'vita',
#   'parvus',
#   'gemo',
#   'lacrima',
#   'sum1',
#   'floreo',
#   'invidus',
#   'carpo',
#   'annus',
#   'teneo',
#   'talis',
#   'communio1',
#   'causa',
#   'querela',
#   'meliboee',
#   'jaceo',
#   'mortalis',
#   'frigus',
#   'segnis',
#   'homo',
#   'caelo',
#   'dignus',
#   'caneo',
#   'senecta',
#   'concilio',
#   'plenus',
#   'pondus',
#   'aequus',
#   'pectus',
#   'ruricolum',
#   'discerno',
#   'lito',
#   'assueras',
#   'vario',
#   'patior',
#   'mulceo',
#   'querela',
#   'rus',
#   'reverendus',
#   'jus',
#   'floreo',
#   'ambiguus',
#   'signo',
#   'terminus',
#   'ager',
#   'blandus',
#   'vultus',
#   'gravitas',
#   'serenus1',
#   'frons2',
#   'supercilium',
#   'pectus',
#   'mitis',
#   'calamus',
#   'apto',
#   'labrum1',
#   'jungo',
#   'horto',
#   'duro',
#   'doceo',
#   'fallo',
#   'curo',
#   'segnis',
#   'patior',
#   'marceo',
#   'juventa',
#   'saepis',
#   'do',
#   'mereo',
#   'vilis',
#   'praemium',
#   'musae',
#   'saepis',
#   'seni',
#   'canto',
#   'pigeo',
#   'laetus1',
#   'phoebea',
#   'dico2',
#   'carmen1',
#   'avena',
#   'felix1',
#   'meliboee',
#   'frons1',
#   'odorus',
#   'munero',
#   'laurus',
#   'carpo',
#   'ruralis',
#   'apollo',
#   'fauni',
#   'valeo',
#   'racemus',
#   'meto2',
#   'culmus',
#   'omne',
#   'arbor1',
#   'frugis',
#   'grandaevus',
#   'palo',
#   'spumo',
#   'cymbium',
#   'lacteo',
#   'mel',
#   'fero',
#   'nympha',
#   'pingo',
#   'florus1',
#   'corono',
#   'manus1',
#   'superus',
#   'honor',
#   'carmen1',
#   'musae',
#   'carmen1',
#   'musae',
#   'modulamur',
#   'avena',
#   'siluestris',
#   'platanus',
#   'meliboee',
#   'susurro1',
#   'pinus',
#   'reboo',
#   'carmen1',
#   'respondeo',
#   'silva',
#   'armentum',
#   'loquor',
#   'prior',
#   'siccus',
#   'phoca',
#   'pasco',
#   'arvum',
#   'vestio',
#   'fretus1',
#   'vivo',
#   'dulcia',
#   'mel',
#   'sudo',
#   'confundo',
#   'lex',
#   'messis',
#   'tero',
#   'hiems',
#   'aestas',
#   'tracto',
#   'oliva',
#   'do',
#   'floreo',
#   'auctumnus1',
#   'do',
#   'taceo',
#   'meliboee',
#   'fistula',
#   'laudo',
#   'pergo',
#   'coepio',
#   'desero2',
#   'carmen1',
#   'dulcis',
#   'sono',
#   'placo',
#   'apollo',
#   'prouehat',
#   'felix1',
#   'domina',
#   'perduco',
#   'urbs',
#   'jam',
#   'silva',
#   'praesens',
#   'benignus',
#   'sterno',
#   'rumpo',
#   'liuoris',
#   'nubilus',
#   'pinnis',
#   'demitto',
#   'equus1',
#   'culmen',
#   'mundus',
#   'fulmineus',
#   'suadeo',
#   'grex',
#   'praebeo',
#   'liquor2'],
#  ['populeus',
#   'lycidas',
#   'mopsus',
#   'umbro',
#   'pastor',
#   'calamus',
#   'verro',
#   'doceo',
#   'uter',
#   'trivialis',
#   'sono',
#   'proprius',
#   'canto',
#   'amor',
#   'mopso',
#   'meroe',
#   'lycidae',
#   'crinio',
#   'iollas',
#   'ignis',
#   'parilisque',
#   'furo',
#   'dis-pareo',
#   'cogo',
#   'trepidus',
#   'totus1',
#   'discurro',
#   'silva',
#   'meroe',
#   'multus',
#   'ludo',
#   'furo',
#   'condictas',
#   'vito',
#   'valles',
#   'ulmus',
#   'fagus',
#   'placeo',
#   'fugio',
#   'promitto',
#   'fallo',
#   'antrum',
#   'animus',
#   'soleo',
#   'ludo',
#   'fons',
#   'tandem',
#   'fatisco',
#   'durus',
#   'ador',
#   'ignis',
#   'desero2',
#   'nudo',
#   'vulnero',
#   'silva',
#   'inquam',
#   'vicis',
#   'dulcis',
#   'cano',
#   'dico2',
#   'querela',
#   'immitis',
#   'meroe',
#   'rapidus',
#   'fugax',
#   'eurus',
#   'calamus',
#   'pastoralis',
#   'vito',
#   'carmen1',
#   'qui1',
#   'fugio',
#   'glorior',
#   'vinco',
#   'vultus',
#   'mens',
#   'premo',
#   'frons2',
#   'serenus1',
#   'tandem',
#   'volo1',
#   'nego',
#   'canto',
#   'levo1',
#   'carmen1',
#   'curo',
#   'respicio',
#   'tandem',
#   'crudelis',
#   'iolla',
#   'semper',
#   'perdo',
#   'gramen',
#   'floreo',
#   'perdo',
#   'spina',
#   'rodo',
#   'semper',
#   'lilium',
#   'candeo',
#   'longus',
#   'teneo',
#   'como1',
#   'populus1',
#   'umbro',
#   'donum',
#   'formo',
#   'brevis',
#   'commodo2',
#   'annus',
#   'canto',
#   'levo1',
#   'carmen1',
#   'curo',
#   'cerva',
#   'marem',
#   'sequor',
#   'taurus1',
#   'formosus',
#   'juvencus1',
#   'uenerem',
#   'sentio',
#   'lupa',
#   'sentio',
#   'leaena1',
#   'genus1',
#   'aerius',
#   'volucris',
#   'squameus',
#   'turbo1',
#   'mons',
#   'silva',
#   'habeo',
#   'arbor1',
#   'amor',
#   'fugio',
#   'miser',
#   'prodeo',
#   'amo',
#   'canto',
#   'levo1',
#   'carmen1',
#   'curo',
#   'omne',
#   'tempus',
#   'tempus',
#   'rapio',
#   'vitulus',
#   'mater',
#   'iste',
#   'niveus',
#   'coeo',
#   'cornu',
#   'vacca1',
#   'tumidus',
#   'no1',
#   'fortis',
#   'collum',
#   'deni',
#   'numero1',
#   'messis',
#   'canto',
#   'levo1',
#   'carmen1',
#   'curo',
#   'meroe',
#   'formosus',
#   'voco',
#   'aestus',
#   'umbra',
#   'pecus2',
#   'subeo',
#   'no1',
#   'nullus',
#   'canorus',
#   'guttur',
#   'canto',
#   'torqueo',
#   'squameus',
#   'traho',
#   'signo',
#   'humus',
#   'serpo',
#   'solus',
#   'sono',
#   'omne',
#   'silva',
#   'aestivus',
#   'cano',
#   'concedo',
#   'cicada',
#   'canto',
#   'levo1',
#   'carmen1',
#   'curo',
#   'saevus',
#   'niveus',
#   'perdo',
#   'coloro',
#   'solo1',
#   'luceo',
#   'uro',
#   'mala',
#   'pampineus',
#   'requiesco',
#   'umbro',
#   'vireo1',
#   'murmurat',
#   'ulmus',
#   'purpureus',
#   'for',
#   'dependo',
#   'vitis',
#   'canto',
#   'levo1',
#   'carmen1',
#   'curo',
#   'fero',
#   'meroes',
#   'fastidium',
#   'lentus',
#   'superbus',
#   'sithonias',
#   'fero',
#   'nix',
#   'libyaeque',
#   'calor1',
#   'nerinas',
#   'poto',
#   'aqua',
#   'taxus',
#   'noceo',
#   'metuo',
#   'sucus',
#   'sardorum',
#   'gramen',
#   'vinco',
#   'marmaricos',
#   'cogo',
#   'fero',
#   'leo2',
#   'canto',
#   'levo1',
#   'carmen1',
#   'curo',
#   'puer',
#   'ferrum',
#   'praecordia',
#   'duro',
#   'propero',
#   'disco',
#   'patienter',
#   'amo',
#   'prudens',
#   'animus',
#   'teneo',
#   'sperno',
#   'annus',
#   'perfero',
#   'fastus1',
#   'gaudium',
#   'sumo',
#   'sollicitus',
#   'audio',
#   'amo',
#   'canto',
#   'levo1',
#   'carmen1',
#   'curo',
#   'prodo',
#   'paganus',
#   'mater',
#   'amyntae',
#   'vitta',
#   'frondeo',
#   'sacro',
#   'uaporo',
#   'incendo',
#   'crepitantes',
#   'sulphure',
#   'laurus',
#   'lustro1',
#   'cinis',
#   'averto',
#   'effundo',
#   'amnis',
#   'canto',
#   'levo1',
#   'carmen1',
#   'curo',
#   'meroen',
#   'totus1',
#   'miser',
#   'ignis',
#   'versicoloria',
#   'mille',
#   'ignosco',
#   'mycale',
#   'circumfero',
#   'herba',
#   'canto',
#   'tumeo',
#   'rumpo',
#   'anguis',
#   'curro',
#   'scopulus',
#   'migro',
#   'vello',
#   'arbos',
#   'formosus',
#   'iollas',
#   'canto',
#   'levo1',
#   'carmen1',
#   'curo']]

# %%
# Do a basic count of the words in the texts, just to get a rough idea of the data.
from collections import Counter
text_list = []
for i in text_data:
    for word in i:
        text_list.append(word)
Counter(text_list).most_common(20)
# Out:
# [('carmen1', 36),
#  ('canto', 22),
#  ('silva', 16),
#  ('venio', 16),
#  ('amor', 14),
#  ('video', 13),
#  ('dico2', 13),
#  ('grex', 12),
#  ('pecus2', 12),
#  ('fero', 12),
#  ('omne', 12),
#  ('curo', 12),
#  ('tempus', 11),
#  ('levo1', 11),
#  ('cano', 11),
#  ('herba', 10),
#  ('incipio', 9),
#  ('tantus', 9),
#  ('sequor', 9),
#  ('calamus', 9)]

# %%
# Make a dictionary out of the data
from gensim import corpora
dictionary = corpora.Dictionary(text_data)

# %%
# Turn the dictionary into a "bag of words" corpus.
corpus = [dictionary.doc2bow(text) for text in text_data]

# %%
# Display the "bag of words" corpus.
corpus
# Out:
# [[(0, 2),
#   (1, 1),
#   (2, 1),
#   (3, 1),
#   (4, 1),
#   (5, 1),
#   (6, 1),
#   (7, 3),
#   (8, 1),
#   (9, 1),
#   (10, 1),
#   (11, 2),
#   (12, 1),
#   (13, 2),
#   (14, 1),
#   (15, 2),
#   (16, 1),
#   (17, 2),
#   (18, 1),
#   (19, 1),
#   (20, 2),
#   (21, 1),
#   (22, 1),
#   (23, 1),
#   (24, 1),
#   (25, 1),
#   (26, 1),
#   (27, 1),
#   (28, 2),
#   (29, 1),
#   (30, 1),
#   (31, 2),
#   (32, 1),
#   (33, 2),
#   (34, 1),
#   (35, 1),
#   (36, 2),
#   (37, 1),
#   (38, 1),
#   (39, 1),
#   (40, 1),
#   (41, 1),
#   (42, 1),
#   (43, 3),
#   (44, 1),
#   (45, 3),
#   (46, 1),
#   (47, 3),
#   (48, 1),
#   (49, 1),
#   (50, 1),
#   (51, 1),
#   (52, 1),
#   (53, 1),
#   (54, 1),
#   (55, 1),
#   (56, 1),
#   (57, 2),
#   (58, 1),
#   (59, 1),
#   (60, 1),
#   (61, 1),
#   (62, 1),
#   (63, 1),
#   (64, 1),
#   (65, 2),
#   (66, 1),
#   (67, 1),
#   (68, 1),
#   (69, 1),
#   (70, 2),
#   (71, 1),
#   (72, 2),
#   (73, 1),
#   (74, 2),
#   (75, 1),
#   (76, 1),
#   (77, 1),
#   (78, 1),
#   (79, 1),
#   (80, 1),
#   (81, 1),
#   (82, 1),
#   (83, 1),
#   (84, 1),
#   (85, 1),
#   (86, 2),
#   (87, 2),
#   (88, 1),
#   (89, 1),
#   (90, 2),
#   (91, 1),
#   (92, 1),
#   (93, 2),
#   (94, 1),
#   (95, 1),
#   (96, 1),
#   (97, 1),
#   (98, 1),
#   (99, 1),
#   (100, 1),
#   (101, 1),
#   (102, 1),
#   (103, 1),
#   (104, 1),
#   (105, 2),
#   (106, 1),
#   (107, 1),
#   (108, 1),
#   (109, 1),
#   (110, 1),
#   (111, 1),
#   (112, 1),
#   (113, 1),
#   (114, 1),
#   (115, 1),
#   (116, 1),
#   (117, 3),
#   (118, 2),
#   (119, 1),
#   (120, 1),
#   (121, 1),
#   (122, 1),
#   (123, 3),
#   (124, 1),
#   (125, 1),
#   (126, 1),
#   (127, 1),
#   (128, 1),
#   (129, 1),
#   (130, 1),
#   (131, 1),
#   (132, 1),
#   (133, 1),
#   (134, 1),
#   (135, 3),
#   (136, 7),
#   (137, 1),
#   (138, 1),
#   (139, 4),
#   (140, 1),
#   (141, 2),
#   (142, 1),
#   (143, 1),
#   (144, 1),
#   (145, 3),
#   (146, 1),
#   (147, 1),
#   (148, 1),
#   (149, 1),
#   (150, 1),
#   (151, 1),
#   (152, 1),
#   (153, 3),
#   (154, 1),
#   (155, 2),
#   (156, 1),
#   (157, 1),
#   (158, 1),
#   (159, 1),
#   (160, 1),
#   (161, 2),
#   (162, 1),
#   (163, 1),
#   (164, 1),
#   (165, 1),
#   (166, 1),
#   (167, 2),
#   (168, 1),
#   (169, 1),
#   (170, 2),
#   (171, 1),
#   (172, 1),
#   (173, 1),
#   (174, 1),
#   (175, 1),
#   (176, 1),
#   (177, 1),
#   (178, 1),
#   (179, 1),
#   (180, 2),
#   (181, 1),
#   (182, 1),
#   (183, 1),
#   (184, 1),
#   (185, 2),
#   (186, 1),
#   (187, 1),
#   (188, 3),
#   (189, 1),
#   (190, 1),
#   (191, 1),
#   (192, 3),
#   (193, 1),
#   (194, 1),
#   (195, 1),
#   (196, 1),
#   (197, 1),
#   (198, 2),
#   (199, 1),
#   (200, 1),
#   (201, 1),
#   (202, 1),
#   (203, 1),
#   (204, 1),
#   (205, 1),
#   (206, 1),
#   (207, 1),
#   (208, 1),
#   (209, 1),
#   (210, 1),
#   (211, 1),
#   (212, 2),
#   (213, 2),
#   (214, 1),
#   (215, 1),
#   (216, 2),
#   (217, 1),
#   (218, 1),
#   (219, 1),
#   (220, 1),
#   (221, 1),
#   (222, 3),
#   (223, 1),
#   (224, 1),
#   (225, 2),
#   (226, 1),
#   (227, 2),
#   (228, 1),
#   (229, 2),
#   (230, 1),
#   (231, 1),
#   (232, 1),
#   (233, 3),
#   (234, 1),
#   (235, 1),
#   (236, 1),
#   (237, 1),
#   (238, 1),
#   (239, 1),
#   (240, 1),
#   (241, 1),
#   (242, 1),
#   (243, 1),
#   (244, 1),
#   (245, 1),
#   (246, 4),
#   (247, 1),
#   (248, 1),
#   (249, 1),
#   (250, 1),
#   (251, 1),
#   (252, 1),
#   (253, 1),
#   (254, 1),
#   (255, 1),
#   (256, 2),
#   (257, 1),
#   (258, 1),
#   (259, 1),
#   (260, 1),
#   (261, 6),
#   (262, 1),
#   (263, 1),
#   (264, 1),
#   (265, 1),
#   (266, 1),
#   (267, 1),
#   (268, 1),
#   (269, 1),
#   (270, 1),
#   (271, 1),
#   (272, 1),
#   (273, 2),
#   (274, 1),
#   (275, 3),
#   (276, 1),
#   (277, 1),
#   (278, 2),
#   (279, 1),
#   (280, 1),
#   (281, 3),
#   (282, 1),
#   (283, 1),
#   (284, 1),
#   (285, 1),
#   (286, 1),
#   (287, 2),
#   (288, 1),
#   (289, 1),
#   (290, 1),
#   (291, 1),
#   (292, 1),
#   (293, 1),
#   (294, 1),
#   (295, 1),
#   (296, 1),
#   (297, 1),
#   (298, 1),
#   (299, 1),
#   (300, 1),
#   (301, 1),
#   (302, 2),
#   (303, 1),
#   (304, 1),
#   (305, 1),
#   (306, 1),
#   (307, 1),
#   (308, 1),
#   (309, 1),
#   (310, 1),
#   (311, 1),
#   (312, 1),
#   (313, 1),
#   (314, 1),
#   (315, 1),
#   (316, 1),
#   (317, 1),
#   (318, 1),
#   (319, 2),
#   (320, 1),
#   (321, 1),
#   (322, 1),
#   (323, 2),
#   (324, 1),
#   (325, 1),
#   (326, 1),
#   (327, 1),
#   (328, 1),
#   (329, 1),
#   (330, 1),
#   (331, 1),
#   (332, 1),
#   (333, 3),
#   (334, 1),
#   (335, 1),
#   (336, 1),
#   (337, 1),
#   (338, 1),
#   (339, 1),
#   (340, 2),
#   (341, 3),
#   (342, 2),
#   (343, 1),
#   (344, 1),
#   (345, 1),
#   (346, 1),
#   (347, 1),
#   (348, 1),
#   (349, 1),
#   (350, 1),
#   (351, 1),
#   (352, 2),
#   (353, 1),
#   (354, 1),
#   (355, 1),
#   (356, 1),
#   (357, 1),
#   (358, 3),
#   (359, 1),
#   (360, 1),
#   (361, 1),
#   (362, 1),
#   (363, 1),
#   (364, 1),
#   (365, 1),
#   (366, 1),
#   (367, 4),
#   (368, 1),
#   (369, 1),
#   (370, 1),
#   (371, 1),
#   (372, 2),
#   (373, 1),
#   (374, 1),
#   (375, 1),
#   (376, 1),
#   (377, 2),
#   (378, 2),
#   (379, 1),
#   (380, 4),
#   (381, 1),
#   (382, 1),
#   (383, 1),
#   (384, 1),
#   (385, 1),
#   (386, 1),
#   (387, 1),
#   (388, 1),
#   (389, 3),
#   (390, 1),
#   (391, 1),
#   (392, 1),
#   (393, 1),
#   (394, 1),
#   (395, 1),
#   (396, 1),
#   (397, 1),
#   (398, 1),
#   (399, 1),
#   (400, 1),
#   (401, 1),
#   (402, 1),
#   (403, 1),
#   (404, 2),
#   (405, 1),
#   (406, 1),
#   (407, 1),
#   (408, 3),
#   (409, 1),
#   (410, 1),
#   (411, 1),
#   (412, 1),
#   (413, 1),
#   (414, 1),
#   (415, 1),
#   (416, 1),
#   (417, 1),
#   (418, 1),
#   (419, 1),
#   (420, 1),
#   (421, 2),
#   (422, 1),
#   (423, 2),
#   (424, 2)],
#  [(17, 6),
#   (33, 1),
#   (47, 3),
#   (52, 2),
#   (100, 1),
#   (111, 1),
#   (114, 1),
#   (121, 4),
#   (123, 1),
#   (127, 1),
#   (129, 2),
#   (135, 1),
#   (136, 1),
#   (140, 1),
#   (141, 1),
#   (145, 1),
#   (153, 1),
#   (164, 1),
#   (167, 2),
#   (175, 1),
#   (180, 2),
#   (181, 1),
#   (190, 1),
#   (192, 1),
#   (194, 2),
#   (199, 2),
#   (210, 1),
#   (213, 1),
#   (214, 1),
#   (216, 1),
#   (232, 3),
#   (233, 1),
#   (255, 1),
#   (270, 1),
#   (280, 1),
#   (283, 1),
#   (297, 1),
#   (319, 2),
#   (324, 2),
#   (334, 1),
#   (341, 3),
#   (344, 1),
#   (351, 1),
#   (358, 1),
#   (362, 1),
#   (364, 2),
#   (365, 1),
#   (368, 2),
#   (389, 2),
#   (405, 1),
#   (408, 3),
#   (413, 1),
#   (425, 1),
#   (426, 1),
#   (427, 1),
#   (428, 1),
#   (429, 1),
#   (430, 1),
#   (431, 1),
#   (432, 1),
#   (433, 1),
#   (434, 1),
#   (435, 3),
#   (436, 1),
#   (437, 1),
#   (438, 1),
#   (439, 1),
#   (440, 1),
#   (441, 2),
#   (442, 1),
#   (443, 1),
#   (444, 1),
#   (445, 1),
#   (446, 1),
#   (447, 1),
#   (448, 1),
#   (449, 1),
#   (450, 1),
#   (451, 1),
#   (452, 3),
#   (453, 4),
#   (454, 1),
#   (455, 5),
#   (456, 1),
#   (457, 1),
#   (458, 1),
#   (459, 1),
#   (460, 1),
#   (461, 2),
#   (462, 1),
#   (463, 1),
#   (464, 1),
#   (465, 1),
#   (466, 3),
#   (467, 1),
#   (468, 1),
#   (469, 1),
#   (470, 1),
#   (471, 1),
#   (472, 1),
#   (473, 3),
#   (474, 1),
#   (475, 1),
#   (476, 1),
#   (477, 1),
#   (478, 1),
#   (479, 1),
#   (480, 1),
#   (481, 1),
#   (482, 2),
#   (483, 1),
#   (484, 1),
#   (485, 1),
#   (486, 1),
#   (487, 2),
#   (488, 1),
#   (489, 1),
#   (490, 1),
#   (491, 1),
#   (492, 1),
#   (493, 1),
#   (494, 7),
#   (495, 1),
#   (496, 1),
#   (497, 1),
#   (498, 1),
#   (499, 2),
#   (500, 1),
#   (501, 1),
#   (502, 1),
#   (503, 1),
#   (504, 1),
#   (505, 1),
#   (506, 1),
#   (507, 1),
#   (508, 1),
#   (509, 1),
#   (510, 1),
#   (511, 3),
#   (512, 1),
#   (513, 1),
#   (514, 1),
#   (515, 1),
#   (516, 2),
#   (517, 1),
#   (518, 1),
#   (519, 2),
#   (520, 1),
#   (521, 1),
#   (522, 1),
#   (523, 2),
#   (524, 1),
#   (525, 1),
#   (526, 1),
#   (527, 1),
#   (528, 1),
#   (529, 1),
#   (530, 1),
#   (531, 1),
#   (532, 1),
#   (533, 1),
#   (534, 1),
#   (535, 1),
#   (536, 1),
#   (537, 1),
#   (538, 1),
#   (539, 1),
#   (540, 1),
#   (541, 1),
#   (542, 2),
#   (543, 1),
#   (544, 1),
#   (545, 2),
#   (546, 1),
#   (547, 1),
#   (548, 2),
#   (549, 1),
#   (550, 1),
#   (551, 1),
#   (552, 1),
#   (553, 1),
#   (554, 1),
#   (555, 1),
#   (556, 2),
#   (557, 2),
#   (558, 1),
#   (559, 1),
#   (560, 1),
#   (561, 1),
#   (562, 2),
#   (563, 1),
#   (564, 1),
#   (565, 1),
#   (566, 1),
#   (567, 1),
#   (568, 1),
#   (569, 1),
#   (570, 1),
#   (571, 1),
#   (572, 1),
#   (573, 1),
#   (574, 1),
#   (575, 1),
#   (576, 1),
#   (577, 1),
#   (578, 1),
#   (579, 1),
#   (580, 1),
#   (581, 1),
#   (582, 1),
#   (583, 1),
#   (584, 1),
#   (585, 1),
#   (586, 1),
#   (587, 1),
#   (588, 1),
#   (589, 1),
#   (590, 1),
#   (591, 1),
#   (592, 1),
#   (593, 1),
#   (594, 1),
#   (595, 1),
#   (596, 1),
#   (597, 1),
#   (598, 1),
#   (599, 1),
#   (600, 1),
#   (601, 1),
#   (602, 1),
#   (603, 1),
#   (604, 1),
#   (605, 1),
#   (606, 8),
#   (607, 1),
#   (608, 1),
#   (609, 1),
#   (610, 4),
#   (611, 1),
#   (612, 1),
#   (613, 1),
#   (614, 1)],
#  [(0, 1),
#   (17, 2),
#   (36, 1),
#   (44, 1),
#   (49, 1),
#   (60, 1),
#   (62, 2),
#   (81, 1),
#   (84, 1),
#   (93, 3),
#   (105, 3),
#   (114, 1),
#   (117, 1),
#   (124, 2),
#   (136, 1),
#   (139, 2),
#   (147, 1),
#   (150, 1),
#   (153, 2),
#   (167, 2),
#   (180, 1),
#   (185, 1),
#   (190, 1),
#   (216, 4),
#   (231, 2),
#   (233, 1),
#   (254, 1),
#   (255, 1),
#   (261, 1),
#   (283, 1),
#   (294, 1),
#   (297, 2),
#   (298, 1),
#   (307, 3),
#   (308, 1),
#   (324, 1),
#   (334, 4),
#   (341, 2),
#   (342, 2),
#   (344, 2),
#   (345, 1),
#   (346, 1),
#   (358, 3),
#   (364, 3),
#   (365, 1),
#   (367, 1),
#   (368, 1),
#   (408, 4),
#   (413, 1),
#   (422, 1),
#   (423, 1),
#   (430, 1),
#   (431, 1),
#   (432, 1),
#   (434, 2),
#   (438, 1),
#   (451, 1),
#   (452, 4),
#   (453, 1),
#   (454, 3),
#   (455, 5),
#   (473, 4),
#   (489, 1),
#   (494, 1),
#   (499, 1),
#   (511, 1),
#   (518, 1),
#   (526, 2),
#   (536, 1),
#   (537, 1),
#   (538, 1),
#   (541, 2),
#   (542, 1),
#   (544, 2),
#   (545, 3),
#   (552, 2),
#   (558, 1),
#   (563, 1),
#   (572, 1),
#   (574, 1),
#   (578, 1),
#   (579, 2),
#   (587, 1),
#   (595, 1),
#   (598, 1),
#   (608, 1),
#   (615, 1),
#   (616, 1),
#   (617, 1),
#   (618, 2),
#   (619, 1),
#   (620, 1),
#   (621, 1),
#   (622, 1),
#   (623, 1),
#   (624, 1),
#   (625, 1),
#   (626, 1),
#   (627, 2),
#   (628, 1),
#   (629, 1),
#   (630, 1),
#   (631, 1),
#   (632, 1),
#   (633, 1),
#   (634, 1),
#   (635, 1),
#   (636, 1),
#   (637, 1),
#   (638, 1),
#   (639, 2),
#   (640, 1),
#   (641, 1),
#   (642, 1),
#   (643, 1),
#   (644, 1),
#   (645, 1),
#   (646, 2),
#   (647, 1),
#   (648, 1),
#   (649, 1),
#   (650, 1),
#   (651, 1),
#   (652, 1),
#   (653, 1),
#   (654, 1),
#   (655, 1),
#   (656, 1),
#   (657, 1),
#   (658, 1),
#   (659, 1),
#   (660, 1),
#   (661, 2),
#   (662, 1),
#   (663, 1),
#   (664, 1),
#   (665, 1),
#   (666, 1),
#   (667, 1),
#   (668, 1),
#   (669, 1),
#   (670, 1),
#   (671, 1),
#   (672, 1),
#   (673, 1),
#   (674, 1),
#   (675, 1),
#   (676, 1),
#   (677, 1),
#   (678, 1),
#   (679, 1),
#   (680, 1),
#   (681, 1),
#   (682, 1),
#   (683, 1),
#   (684, 1),
#   (685, 1),
#   (686, 1),
#   (687, 1),
#   (688, 1),
#   (689, 1),
#   (690, 1),
#   (691, 1),
#   (692, 1),
#   (693, 1),
#   (694, 1),
#   (695, 1),
#   (696, 1),
#   (697, 1),
#   (698, 1),
#   (699, 1),
#   (700, 1),
#   (701, 3),
#   (702, 1),
#   (703, 1),
#   (704, 1),
#   (705, 1),
#   (706, 1),
#   (707, 1),
#   (708, 1),
#   (709, 1),
#   (710, 2),
#   (711, 2),
#   (712, 1),
#   (713, 1),
#   (714, 1),
#   (715, 1),
#   (716, 1),
#   (717, 1),
#   (718, 1),
#   (719, 1),
#   (720, 1),
#   (721, 3),
#   (722, 1),
#   (723, 1),
#   (724, 2),
#   (725, 1),
#   (726, 2),
#   (727, 1),
#   (728, 1),
#   (729, 1),
#   (730, 1),
#   (731, 1),
#   (732, 1),
#   (733, 1),
#   (734, 1),
#   (735, 1),
#   (736, 1),
#   (737, 1),
#   (738, 2),
#   (739, 1),
#   (740, 1),
#   (741, 1),
#   (742, 1),
#   (743, 1),
#   (744, 2),
#   (745, 1),
#   (746, 1),
#   (747, 1),
#   (748, 1),
#   (749, 1),
#   (750, 1),
#   (751, 1),
#   (752, 1),
#   (753, 1),
#   (754, 1),
#   (755, 1),
#   (756, 1),
#   (757, 1),
#   (758, 1),
#   (759, 1),
#   (760, 1),
#   (761, 1),
#   (762, 1),
#   (763, 1),
#   (764, 1),
#   (765, 1),
#   (766, 1),
#   (767, 1),
#   (768, 1),
#   (769, 3),
#   (770, 1),
#   (771, 1),
#   (772, 1),
#   (773, 1),
#   (774, 1),
#   (775, 1),
#   (776, 1),
#   (777, 1),
#   (778, 1),
#   (779, 2),
#   (780, 1),
#   (781, 1),
#   (782, 1),
#   (783, 1),
#   (784, 1),
#   (785, 1),
#   (786, 1),
#   (787, 1),
#   (788, 1),
#   (789, 1),
#   (790, 2),
#   (791, 1),
#   (792, 2),
#   (793, 1),
#   (794, 1),
#   (795, 1),
#   (796, 1),
#   (797, 1),
#   (798, 1),
#   (799, 1),
#   (800, 1),
#   (801, 1),
#   (802, 1),
#   (803, 1),
#   (804, 1),
#   (805, 1),
#   (806, 1),
#   (807, 1),
#   (808, 1),
#   (809, 1),
#   (810, 1),
#   (811, 2),
#   (812, 1),
#   (813, 1),
#   (814, 2),
#   (815, 1),
#   (816, 1),
#   (817, 2),
#   (818, 1),
#   (819, 1),
#   (820, 1),
#   (821, 1),
#   (822, 1),
#   (823, 1),
#   (824, 1),
#   (825, 1),
#   (826, 1),
#   (827, 1),
#   (828, 2),
#   (829, 2),
#   (830, 1)],
#  [(9, 1),
#   (14, 2),
#   (16, 1),
#   (17, 1),
#   (19, 1),
#   (20, 1),
#   (39, 1),
#   (47, 1),
#   (62, 1),
#   (63, 1),
#   (89, 2),
#   (92, 1),
#   (101, 1),
#   (105, 1),
#   (111, 2),
#   (112, 1),
#   (114, 1),
#   (117, 1),
#   (123, 1),
#   (125, 3),
#   (136, 1),
#   (138, 1),
#   (139, 2),
#   (143, 1),
#   (153, 1),
#   (166, 1),
#   (174, 2),
#   (179, 1),
#   (180, 2),
#   (181, 2),
#   (186, 1),
#   (188, 1),
#   (199, 2),
#   (201, 1),
#   (202, 1),
#   (204, 1),
#   (211, 1),
#   (212, 2),
#   (221, 1),
#   (222, 2),
#   (226, 1),
#   (229, 1),
#   (236, 1),
#   (238, 1),
#   (252, 1),
#   (253, 1),
#   (255, 3),
#   (258, 1),
#   (261, 4),
#   (271, 1),
#   (273, 2),
#   (277, 1),
#   (280, 1),
#   (297, 3),
#   (298, 1),
#   (299, 1),
#   (307, 1),
#   (329, 1),
#   (334, 2),
#   (339, 3),
#   (341, 2),
#   (347, 1),
#   (350, 1),
#   (356, 1),
#   (362, 1),
#   (364, 3),
#   (367, 2),
#   (368, 1),
#   (381, 1),
#   (398, 1),
#   (404, 2),
#   (406, 1),
#   (408, 3),
#   (431, 1),
#   (434, 1),
#   (435, 2),
#   (437, 1),
#   (440, 2),
#   (445, 1),
#   (449, 1),
#   (451, 1),
#   (453, 2),
#   (455, 5),
#   (459, 1),
#   (462, 2),
#   (464, 1),
#   (465, 2),
#   (469, 1),
#   (473, 2),
#   (476, 1),
#   (481, 1),
#   (482, 4),
#   (486, 2),
#   (487, 1),
#   (489, 1),
#   (490, 1),
#   (491, 2),
#   (492, 1),
#   (500, 3),
#   (509, 1),
#   (511, 1),
#   (512, 1),
#   (518, 1),
#   (519, 1),
#   (526, 2),
#   (528, 1),
#   (536, 1),
#   (540, 1),
#   (543, 1),
#   (544, 1),
#   (545, 4),
#   (555, 4),
#   (558, 1),
#   (563, 1),
#   (569, 1),
#   (571, 1),
#   (573, 2),
#   (578, 1),
#   (606, 7),
#   (610, 1),
#   (632, 1),
#   (638, 1),
#   (645, 1),
#   (646, 1),
#   (657, 1),
#   (686, 1),
#   (694, 1),
#   (698, 1),
#   (699, 1),
#   (701, 1),
#   (715, 1),
#   (716, 1),
#   (719, 1),
#   (728, 2),
#   (733, 1),
#   (734, 1),
#   (745, 1),
#   (747, 1),
#   (756, 1),
#   (765, 2),
#   (769, 1),
#   (771, 1),
#   (774, 1),
#   (779, 5),
#   (796, 2),
#   (801, 1),
#   (805, 1),
#   (814, 2),
#   (818, 2),
#   (819, 1),
#   (831, 1),
#   (832, 1),
#   (833, 2),
#   (834, 1),
#   (835, 1),
#   (836, 1),
#   (837, 1),
#   (838, 1),
#   (839, 1),
#   (840, 3),
#   (841, 1),
#   (842, 1),
#   (843, 1),
#   (844, 1),
#   (845, 1),
#   (846, 1),
#   (847, 1),
#   (848, 1),
#   (849, 1),
#   (850, 1),
#   (851, 1),
#   (852, 1),
#   (853, 1),
#   (854, 1),
#   (855, 1),
#   (856, 1),
#   (857, 2),
#   (858, 1),
#   (859, 1),
#   (860, 1),
#   (861, 1),
#   (862, 1),
#   (863, 1),
#   (864, 1),
#   (865, 3),
#   (866, 1),
#   (867, 1),
#   (868, 1),
#   (869, 1),
#   (870, 1),
#   (871, 1),
#   (872, 1),
#   (873, 1),
#   (874, 1),
#   (875, 1),
#   (876, 1),
#   (877, 1),
#   (878, 2),
#   (879, 1),
#   (880, 1),
#   (881, 1),
#   (882, 1),
#   (883, 1),
#   (884, 1),
#   (885, 2),
#   (886, 1),
#   (887, 1),
#   (888, 1),
#   (889, 1),
#   (890, 1),
#   (891, 1),
#   (892, 1),
#   (893, 1),
#   (894, 1),
#   (895, 1),
#   (896, 1),
#   (897, 1),
#   (898, 1),
#   (899, 1),
#   (900, 2),
#   (901, 2),
#   (902, 1),
#   (903, 1),
#   (904, 1),
#   (905, 2),
#   (906, 1),
#   (907, 1),
#   (908, 1),
#   (909, 1),
#   (910, 1),
#   (911, 1),
#   (912, 2),
#   (913, 1),
#   (914, 2),
#   (915, 1),
#   (916, 1),
#   (917, 1),
#   (918, 1),
#   (919, 1),
#   (920, 1),
#   (921, 1),
#   (922, 1),
#   (923, 1),
#   (924, 1),
#   (925, 2),
#   (926, 2),
#   (927, 1),
#   (928, 1),
#   (929, 1),
#   (930, 1),
#   (931, 1),
#   (932, 1),
#   (933, 1),
#   (934, 1),
#   (935, 1),
#   (936, 1),
#   (937, 1),
#   (938, 2),
#   (939, 1),
#   (940, 1),
#   (941, 1),
#   (942, 2),
#   (943, 2),
#   (944, 2),
#   (945, 1),
#   (946, 1),
#   (947, 2),
#   (948, 2),
#   (949, 2),
#   (950, 1),
#   (951, 1),
#   (952, 1),
#   (953, 2),
#   (954, 1),
#   (955, 1),
#   (956, 1),
#   (957, 1),
#   (958, 1),
#   (959, 2),
#   (960, 1),
#   (961, 1),
#   (962, 1),
#   (963, 1),
#   (964, 1),
#   (965, 1),
#   (966, 1),
#   (967, 1),
#   (968, 1),
#   (969, 1),
#   (970, 3),
#   (971, 1),
#   (972, 3),
#   (973, 3),
#   (974, 1),
#   (975, 1),
#   (976, 1),
#   (977, 1),
#   (978, 1),
#   (979, 1),
#   (980, 1),
#   (981, 1),
#   (982, 1),
#   (983, 1),
#   (984, 2),
#   (985, 1),
#   (986, 1),
#   (987, 1),
#   (988, 1),
#   (989, 1),
#   (990, 1),
#   (991, 1),
#   (992, 1),
#   (993, 1),
#   (994, 1),
#   (995, 1),
#   (996, 2),
#   (997, 1),
#   (998, 1),
#   (999, 1),
#   (1000, 1),
#   (1001, 1),
#   (1002, 1),
#   (1003, 1),
#   (1004, 2),
#   (1005, 1),
#   (1006, 1),
#   (1007, 1),
#   (1008, 1),
#   (1009, 1),
#   (1010, 1),
#   (1011, 2),
#   (1012, 1),
#   (1013, 1),
#   (1014, 1),
#   (1015, 1),
#   (1016, 1),
#   (1017, 1),
#   (1018, 1),
#   (1019, 1),
#   (1020, 1),
#   (1021, 2),
#   (1022, 1),
#   (1023, 2),
#   (1024, 4),
#   (1025, 1),
#   (1026, 1)],
#  [(0, 2),
#   (10, 1),
#   (17, 1),
#   (20, 3),
#   (32, 1),
#   (33, 1),
#   (43, 1),
#   (49, 1),
#   (51, 1),
#   (55, 1),
#   (58, 1),
#   (60, 1),
#   (62, 1),
#   (63, 1),
#   (65, 1),
#   (74, 1),
#   (79, 1),
#   (84, 1),
#   (87, 4),
#   (89, 1),
#   (105, 3),
#   (111, 3),
#   (121, 1),
#   (124, 1),
#   (135, 2),
#   (136, 2),
#   (139, 1),
#   (141, 1),
#   (153, 2),
#   (167, 1),
#   (169, 1),
#   (170, 1),
#   (171, 1),
#   (174, 1),
#   (186, 1),
#   (188, 1),
#   (196, 1),
#   (201, 2),
#   (204, 1),
#   (212, 1),
#   (220, 1),
#   (233, 1),
#   (249, 1),
#   (254, 1),
#   (255, 1),
#   (267, 1),
#   (269, 1),
#   (270, 1),
#   (271, 1),
#   (282, 1),
#   (283, 1),
#   (295, 2),
#   (318, 1),
#   (328, 1),
#   (330, 1),
#   (332, 1),
#   (333, 3),
#   (336, 1),
#   (339, 1),
#   (340, 1),
#   (341, 2),
#   (345, 1),
#   (348, 1),
#   (349, 1),
#   (358, 1),
#   (361, 2),
#   (362, 1),
#   (366, 1),
#   (367, 2),
#   (371, 1),
#   (396, 1),
#   (413, 2),
#   (419, 1),
#   (421, 2),
#   (438, 3),
#   (440, 1),
#   (447, 3),
#   (452, 2),
#   (453, 2),
#   (455, 10),
#   (468, 1),
#   (473, 3),
#   (485, 1),
#   (486, 2),
#   (491, 1),
#   (497, 1),
#   (500, 2),
#   (505, 1),
#   (506, 1),
#   (517, 1),
#   (518, 1),
#   (519, 1),
#   (534, 1),
#   (544, 1),
#   (545, 1),
#   (566, 2),
#   (567, 1),
#   (573, 1),
#   (577, 1),
#   (587, 3),
#   (591, 1),
#   (598, 1),
#   (599, 1),
#   (606, 1),
#   (608, 1),
#   (619, 1),
#   (627, 1),
#   (632, 1),
#   (638, 5),
#   (639, 1),
#   (671, 1),
#   (678, 1),
#   (687, 1),
#   (691, 1),
#   (702, 1),
#   (710, 1),
#   (711, 2),
#   (716, 4),
#   (717, 1),
#   (719, 1),
#   (721, 1),
#   (728, 1),
#   (732, 2),
#   (733, 3),
#   (742, 1),
#   (750, 1),
#   (763, 1),
#   (764, 1),
#   (765, 1),
#   (770, 1),
#   (787, 1),
#   (789, 1),
#   (792, 2),
#   (811, 1),
#   (818, 1),
#   (822, 1),
#   (863, 1),
#   (867, 2),
#   (870, 1),
#   (888, 2),
#   (907, 1),
#   (914, 1),
#   (926, 1),
#   (937, 1),
#   (943, 1),
#   (953, 1),
#   (969, 1),
#   (994, 1),
#   (998, 1),
#   (1004, 1),
#   (1017, 1),
#   (1019, 1),
#   (1021, 1),
#   (1023, 2),
#   (1027, 1),
#   (1028, 1),
#   (1029, 1),
#   (1030, 1),
#   (1031, 1),
#   (1032, 1),
#   (1033, 1),
#   (1034, 1),
#   (1035, 1),
#   (1036, 1),
#   (1037, 1),
#   (1038, 1),
#   (1039, 1),
#   (1040, 2),
#   (1041, 1),
#   (1042, 1),
#   (1043, 2),
#   (1044, 1),
#   (1045, 1),
#   (1046, 1),
#   (1047, 1),
#   (1048, 1),
#   (1049, 1),
#   (1050, 1),
#   (1051, 1),
#   (1052, 1),
#   (1053, 1),
#   (1054, 1),
#   (1055, 1),
#   (1056, 1),
#   (1057, 1),
#   (1058, 1),
#   (1059, 1),
#   (1060, 1),
#   (1061, 1),
#   (1062, 1),
#   (1063, 1),
#   (1064, 1),
#   (1065, 2),
#   (1066, 1),
#   (1067, 1),
#   (1068, 1),
#   (1069, 1),
#   (1070, 1),
#   (1071, 1),
#   (1072, 1),
#   (1073, 1),
#   (1074, 3),
#   (1075, 1),
#   (1076, 1),
#   (1077, 1),
#   (1078, 1),
#   (1079, 1),
#   (1080, 1),
#   (1081, 1),
#   (1082, 1),
#   (1083, 1),
#   (1084, 1),
#   (1085, 1),
#   (1086, 1),
#   (1087, 1),
#   (1088, 1),
#   (1089, 1),
#   (1090, 1),
#   (1091, 1),
#   (1092, 1),
#   (1093, 1),
#   (1094, 1),
#   (1095, 1),
#   (1096, 1),
#   (1097, 1),
#   (1098, 1),
#   (1099, 1),
#   (1100, 1),
#   (1101, 1),
#   (1102, 1),
#   (1103, 2),
#   (1104, 1),
#   (1105, 1),
#   (1106, 1),
#   (1107, 5),
#   (1108, 1),
#   (1109, 1),
#   (1110, 1),
#   (1111, 1),
#   (1112, 1),
#   (1113, 1),
#   (1114, 1),
#   (1115, 1),
#   (1116, 1),
#   (1117, 1),
#   (1118, 1),
#   (1119, 1),
#   (1120, 1),
#   (1121, 1),
#   (1122, 1),
#   (1123, 1),
#   (1124, 1),
#   (1125, 2),
#   (1126, 3),
#   (1127, 1),
#   (1128, 1),
#   (1129, 1),
#   (1130, 1),
#   (1131, 2),
#   (1132, 1),
#   (1133, 1),
#   (1134, 1),
#   (1135, 1),
#   (1136, 1),
#   (1137, 1),
#   (1138, 1),
#   (1139, 1),
#   (1140, 1),
#   (1141, 1),
#   (1142, 1),
#   (1143, 1),
#   (1144, 1),
#   (1145, 1),
#   (1146, 1),
#   (1147, 1),
#   (1148, 1),
#   (1149, 1),
#   (1150, 2),
#   (1151, 1),
#   (1152, 1),
#   (1153, 1),
#   (1154, 1),
#   (1155, 2),
#   (1156, 1),
#   (1157, 1),
#   (1158, 1),
#   (1159, 1),
#   (1160, 1),
#   (1161, 1),
#   (1162, 1),
#   (1163, 1),
#   (1164, 1),
#   (1165, 1),
#   (1166, 1),
#   (1167, 1),
#   (1168, 1),
#   (1169, 1),
#   (1170, 1),
#   (1171, 1),
#   (1172, 1),
#   (1173, 1),
#   (1174, 1),
#   (1175, 1),
#   (1176, 1)],
#  [(7, 1),
#   (9, 1),
#   (16, 3),
#   (17, 2),
#   (19, 1),
#   (20, 2),
#   (55, 1),
#   (59, 1),
#   (62, 2),
#   (65, 1),
#   (84, 1),
#   (89, 1),
#   (91, 1),
#   (95, 1),
#   (105, 3),
#   (106, 1),
#   (111, 1),
#   (114, 1),
#   (115, 1),
#   (117, 1),
#   (123, 1),
#   (124, 1),
#   (125, 3),
#   (135, 2),
#   (139, 1),
#   (181, 1),
#   (183, 10),
#   (188, 1),
#   (189, 1),
#   (192, 1),
#   (207, 1),
#   (211, 2),
#   (216, 1),
#   (222, 1),
#   (231, 2),
#   (232, 1),
#   (233, 2),
#   (261, 1),
#   (281, 1),
#   (295, 1),
#   (297, 1),
#   (318, 1),
#   (334, 1),
#   (336, 1),
#   (341, 4),
#   (344, 1),
#   (356, 1),
#   (367, 2),
#   (382, 1),
#   (389, 3),
#   (395, 1),
#   (410, 1),
#   (420, 2),
#   (422, 1),
#   (423, 1),
#   (440, 1),
#   (452, 2),
#   (453, 13),
#   (455, 11),
#   (461, 1),
#   (467, 1),
#   (468, 10),
#   (473, 1),
#   (474, 1),
#   (490, 3),
#   (492, 2),
#   (500, 1),
#   (511, 1),
#   (518, 1),
#   (520, 1),
#   (540, 1),
#   (543, 1),
#   (545, 2),
#   (552, 1),
#   (586, 1),
#   (587, 2),
#   (590, 1),
#   (598, 2),
#   (600, 1),
#   (601, 1),
#   (608, 1),
#   (624, 1),
#   (632, 1),
#   (638, 2),
#   (652, 1),
#   (655, 1),
#   (658, 1),
#   (671, 1),
#   (678, 1),
#   (681, 1),
#   (698, 3),
#   (721, 2),
#   (779, 1),
#   (796, 2),
#   (801, 1),
#   (809, 1),
#   (822, 1),
#   (824, 1),
#   (836, 1),
#   (852, 1),
#   (903, 1),
#   (925, 1),
#   (940, 1),
#   (952, 1),
#   (978, 1),
#   (994, 1),
#   (996, 1),
#   (999, 1),
#   (1004, 1),
#   (1007, 2),
#   (1017, 1),
#   (1021, 2),
#   (1025, 1),
#   (1033, 1),
#   (1060, 1),
#   (1065, 1),
#   (1110, 1),
#   (1152, 2),
#   (1171, 2),
#   (1176, 1),
#   (1177, 1),
#   (1178, 1),
#   (1179, 2),
#   (1180, 1),
#   (1181, 1),
#   (1182, 1),
#   (1183, 1),
#   (1184, 1),
#   (1185, 1),
#   (1186, 1),
#   (1187, 1),
#   (1188, 1),
#   (1189, 1),
#   (1190, 1),
#   (1191, 1),
#   (1192, 1),
#   (1193, 1),
#   (1194, 1),
#   (1195, 1),
#   (1196, 1),
#   (1197, 1),
#   (1198, 1),
#   (1199, 1),
#   (1200, 1),
#   (1201, 1),
#   (1202, 1),
#   (1203, 1),
#   (1204, 1),
#   (1205, 1),
#   (1206, 1),
#   (1207, 1),
#   (1208, 1),
#   (1209, 1),
#   (1210, 1),
#   (1211, 2),
#   (1212, 1),
#   (1213, 1),
#   (1214, 1),
#   (1215, 1),
#   (1216, 1),
#   (1217, 1),
#   (1218, 1),
#   (1219, 1),
#   (1220, 1),
#   (1221, 1),
#   (1222, 1),
#   (1223, 2),
#   (1224, 1),
#   (1225, 4),
#   (1226, 1),
#   (1227, 1),
#   (1228, 1),
#   (1229, 1),
#   (1230, 1),
#   (1231, 1),
#   (1232, 1),
#   (1233, 1),
#   (1234, 1),
#   (1235, 1),
#   (1236, 1),
#   (1237, 1),
#   (1238, 1),
#   (1239, 1),
#   (1240, 1),
#   (1241, 3),
#   (1242, 1),
#   (1243, 1),
#   (1244, 1),
#   (1245, 1),
#   (1246, 1),
#   (1247, 1),
#   (1248, 1),
#   (1249, 1),
#   (1250, 1),
#   (1251, 1),
#   (1252, 1),
#   (1253, 1),
#   (1254, 1),
#   (1255, 1),
#   (1256, 1),
#   (1257, 1),
#   (1258, 1),
#   (1259, 1),
#   (1260, 1),
#   (1261, 1),
#   (1262, 1),
#   (1263, 1),
#   (1264, 1),
#   (1265, 1),
#   (1266, 2),
#   (1267, 1),
#   (1268, 1),
#   (1269, 3),
#   (1270, 1),
#   (1271, 1),
#   (1272, 1),
#   (1273, 1),
#   (1274, 1),
#   (1275, 1),
#   (1276, 1),
#   (1277, 1),
#   (1278, 1),
#   (1279, 1),
#   (1280, 1),
#   (1281, 1),
#   (1282, 1),
#   (1283, 1),
#   (1284, 1)]]

# %%
# Save the dictionary
import pickle
pickle.dump(corpus, open('corpus.pkl', 'wb'))
dictionary.save('dictionary.gensim')

# %%
# Creat TF-IDF model object
from gensim import corpora, models

tfidf = models.TfidfModel(corpus)
corpus_tfidf = tfidf[corpus]

from pprint import pprint

for doc in corpus_tfidf:
    pprint(doc)
    break
# Out:
# [(0, 0.036009385221539396),
#  (1, 0.04654145523585096),
#  (2, 0.04654145523585096),
#  (3, 0.04654145523585096),
#  (4, 0.04654145523585096),
#  (5, 0.04654145523585096),
#  (6, 0.04654145523585096),
#  (7, 0.0856102878752438),
#  (8, 0.04654145523585096),
#  (9, 0.018004692610769698),
#  (10, 0.028536762625081268),
#  (11, 0.09308291047170192),
#  (12, 0.04654145523585096),
#  (13, 0.09308291047170192),
#  (14, 0.028536762625081268),
#  (15, 0.09308291047170192),
#  (16, 0.018004692610769698),
#  (18, 0.04654145523585096),
#  (19, 0.018004692610769698),
#  (20, 0.02106414002862313),
#  (21, 0.04654145523585096),
#  (22, 0.04654145523585096),
#  (23, 0.04654145523585096),
#  (24, 0.04654145523585096),
#  (25, 0.04654145523585096),
#  (26, 0.04654145523585096),
#  (27, 0.04654145523585096),
#  (28, 0.09308291047170192),
#  (29, 0.04654145523585096),
#  (30, 0.04654145523585096),
#  (31, 0.09308291047170192),
#  (32, 0.028536762625081268),
#  (33, 0.036009385221539396),
#  (34, 0.04654145523585096),
#  (35, 0.04654145523585096),
#  (36, 0.057073525250162536),
#  (37, 0.04654145523585096),
#  (38, 0.04654145523585096),
#  (39, 0.028536762625081268),
#  (40, 0.04654145523585096),
#  (41, 0.04654145523585096),
#  (42, 0.04654145523585096),
#  (43, 0.0856102878752438),
#  (44, 0.028536762625081268),
#  (45, 0.13962436570755288),
#  (46, 0.04654145523585096),
#  (47, 0.0540140778323091),
#  (48, 0.04654145523585096),
#  (49, 0.018004692610769698),
#  (50, 0.04654145523585096),
#  (51, 0.028536762625081268),
#  (52, 0.028536762625081268),
#  (53, 0.04654145523585096),
#  (54, 0.04654145523585096),
#  (55, 0.018004692610769698),
#  (56, 0.04654145523585096),
#  (57, 0.09308291047170192),
#  (58, 0.028536762625081268),
#  (59, 0.028536762625081268),
#  (60, 0.018004692610769698),
#  (61, 0.04654145523585096),
#  (62, 0.004735853623093905),
#  (63, 0.018004692610769698),
#  (64, 0.04654145523585096),
#  (65, 0.036009385221539396),
#  (66, 0.04654145523585096),
#  (67, 0.04654145523585096),
#  (68, 0.04654145523585096),
#  (69, 0.04654145523585096),
#  (70, 0.09308291047170192),
#  (71, 0.04654145523585096),
#  (72, 0.09308291047170192),
#  (73, 0.04654145523585096),
#  (74, 0.057073525250162536),
#  (75, 0.04654145523585096),
#  (76, 0.04654145523585096),
#  (77, 0.04654145523585096),
#  (78, 0.04654145523585096),
#  (79, 0.028536762625081268),
#  (80, 0.04654145523585096),
#  (81, 0.028536762625081268),
#  (82, 0.04654145523585096),
#  (83, 0.04654145523585096),
#  (84, 0.010532070014311565),
#  (85, 0.04654145523585096),
#  (86, 0.09308291047170192),
#  (87, 0.057073525250162536),
#  (88, 0.04654145523585096),
#  (89, 0.010532070014311565),
#  (90, 0.09308291047170192),
#  (91, 0.028536762625081268),
#  (92, 0.028536762625081268),
#  (93, 0.057073525250162536),
#  (94, 0.04654145523585096),
#  (95, 0.028536762625081268),
#  (96, 0.04654145523585096),
#  (97, 0.04654145523585096),
#  (98, 0.04654145523585096),
#  (99, 0.04654145523585096),
#  (100, 0.028536762625081268),
#  (101, 0.028536762625081268),
#  (102, 0.04654145523585096),
#  (103, 0.04654145523585096),
#  (104, 0.04654145523585096),
#  (105, 0.00947170724618781),
#  (106, 0.028536762625081268),
#  (107, 0.04654145523585096),
#  (108, 0.04654145523585096),
#  (109, 0.04654145523585096),
#  (110, 0.04654145523585096),
#  (111, 0.004735853623093905),
#  (112, 0.028536762625081268),
#  (113, 0.04654145523585096),
#  (114, 0.004735853623093905),
#  (115, 0.028536762625081268),
#  (116, 0.04654145523585096),
#  (117, 0.0315962100429347),
#  (118, 0.09308291047170192),
#  (119, 0.04654145523585096),
#  (120, 0.04654145523585096),
#  (121, 0.018004692610769698),
#  (122, 0.04654145523585096),
#  (123, 0.0315962100429347),
#  (124, 0.010532070014311565),
#  (125, 0.018004692610769698),
#  (126, 0.04654145523585096),
#  (127, 0.028536762625081268),
#  (128, 0.04654145523585096),
#  (129, 0.028536762625081268),
#  (130, 0.04654145523585096),
#  (131, 0.04654145523585096),
#  (132, 0.04654145523585096),
#  (133, 0.04654145523585096),
#  (134, 0.04654145523585096),
#  (135, 0.0315962100429347),
#  (136, 0.033150975361657335),
#  (137, 0.04654145523585096),
#  (138, 0.028536762625081268),
#  (139, 0.01894341449237562),
#  (140, 0.028536762625081268),
#  (141, 0.036009385221539396),
#  (142, 0.04654145523585096),
#  (143, 0.028536762625081268),
#  (144, 0.04654145523585096),
#  (145, 0.0856102878752438),
#  (146, 0.04654145523585096),
#  (147, 0.028536762625081268),
#  (148, 0.04654145523585096),
#  (149, 0.04654145523585096),
#  (150, 0.028536762625081268),
#  (151, 0.04654145523585096),
#  (152, 0.04654145523585096),
#  (153, 0.014207560869281715),
#  (154, 0.04654145523585096),
#  (155, 0.09308291047170192),
#  (156, 0.04654145523585096),
#  (157, 0.04654145523585096),
#  (158, 0.04654145523585096),
#  (159, 0.04654145523585096),
#  (160, 0.04654145523585096),
#  (161, 0.09308291047170192),
#  (162, 0.04654145523585096),
#  (163, 0.04654145523585096),
#  (164, 0.028536762625081268),
#  (165, 0.04654145523585096),
#  (166, 0.028536762625081268),
#  (167, 0.02106414002862313),
#  (168, 0.04654145523585096),
#  (169, 0.028536762625081268),
#  (170, 0.057073525250162536),
#  (171, 0.028536762625081268),
#  (172, 0.04654145523585096),
#  (173, 0.04654145523585096),
#  (174, 0.018004692610769698),
#  (175, 0.028536762625081268),
#  (176, 0.04654145523585096),
#  (177, 0.04654145523585096),
#  (178, 0.04654145523585096),
#  (179, 0.028536762625081268),
#  (180, 0.02106414002862313),
#  (181, 0.010532070014311565),
#  (182, 0.04654145523585096),
#  (183, 0.028536762625081268),
#  (184, 0.04654145523585096),
#  (185, 0.057073525250162536),
#  (186, 0.018004692610769698),
#  (187, 0.04654145523585096),
#  (188, 0.0315962100429347),
#  (189, 0.028536762625081268),
#  (190, 0.018004692610769698),
#  (191, 0.04654145523585096),
#  (192, 0.0540140778323091),
#  (193, 0.04654145523585096),
#  (194, 0.028536762625081268),
#  (195, 0.04654145523585096),
#  (196, 0.028536762625081268),
#  (197, 0.04654145523585096),
#  (198, 0.09308291047170192),
#  (199, 0.018004692610769698),
#  (200, 0.04654145523585096),
#  (201, 0.018004692610769698),
#  (202, 0.028536762625081268),
#  (203, 0.04654145523585096),
#  (204, 0.018004692610769698),
#  (205, 0.04654145523585096),
#  (206, 0.04654145523585096),
#  (207, 0.028536762625081268),
#  (208, 0.04654145523585096),
#  (209, 0.04654145523585096),
#  (210, 0.028536762625081268),
#  (211, 0.018004692610769698),
#  (212, 0.036009385221539396),
#  (213, 0.057073525250162536),
#  (214, 0.028536762625081268),
#  (215, 0.04654145523585096),
#  (216, 0.02106414002862313),
#  (217, 0.04654145523585096),
#  (218, 0.04654145523585096),
#  (219, 0.04654145523585096),
#  (220, 0.028536762625081268),
#  (221, 0.028536762625081268),
#  (222, 0.0540140778323091),
#  (223, 0.04654145523585096),
#  (224, 0.04654145523585096),
#  (225, 0.09308291047170192),
#  (226, 0.028536762625081268),
#  (227, 0.09308291047170192),
#  (228, 0.04654145523585096),
#  (229, 0.057073525250162536),
#  (230, 0.04654145523585096),
#  (231, 0.018004692610769698),
#  (232, 0.018004692610769698),
#  (233, 0.014207560869281715),
#  (234, 0.04654145523585096),
#  (235, 0.04654145523585096),
#  (236, 0.028536762625081268),
#  (237, 0.04654145523585096),
#  (238, 0.028536762625081268),
#  (239, 0.04654145523585096),
#  (240, 0.04654145523585096),
#  (241, 0.04654145523585096),
#  (242, 0.04654145523585096),
#  (243, 0.04654145523585096),
#  (244, 0.04654145523585096),
#  (245, 0.04654145523585096),
#  (246, 0.18616582094340384),
#  (247, 0.04654145523585096),
#  (248, 0.04654145523585096),
#  (249, 0.028536762625081268),
#  (250, 0.04654145523585096),
#  (251, 0.04654145523585096),
#  (252, 0.028536762625081268),
#  (253, 0.028536762625081268),
#  (254, 0.018004692610769698),
#  (255, 0.004735853623093905),
#  (256, 0.09308291047170192),
#  (257, 0.04654145523585096),
#  (258, 0.028536762625081268),
#  (259, 0.04654145523585096),
#  (260, 0.04654145523585096),
#  (261, 0.0631924200858694),
#  (262, 0.04654145523585096),
#  (263, 0.04654145523585096),
#  (264, 0.04654145523585096),
#  (265, 0.04654145523585096),
#  (266, 0.04654145523585096),
#  (267, 0.028536762625081268),
#  (268, 0.04654145523585096),
#  (269, 0.028536762625081268),
#  (270, 0.018004692610769698),
#  (271, 0.018004692610769698),
#  (272, 0.04654145523585096),
#  (273, 0.057073525250162536),
#  (274, 0.04654145523585096),
#  (275, 0.13962436570755288),
#  (276, 0.04654145523585096),
#  (277, 0.028536762625081268),
#  (278, 0.09308291047170192),
#  (279, 0.04654145523585096),
#  (280, 0.018004692610769698),
#  (281, 0.0856102878752438),
#  (282, 0.028536762625081268),
#  (283, 0.010532070014311565),
#  (284, 0.04654145523585096),
#  (285, 0.04654145523585096),
#  (286, 0.04654145523585096),
#  (287, 0.09308291047170192),
#  (288, 0.04654145523585096),
#  (289, 0.04654145523585096),
#  (290, 0.04654145523585096),
#  (291, 0.04654145523585096),
#  (292, 0.04654145523585096),
#  (293, 0.04654145523585096),
#  (294, 0.028536762625081268),
#  (295, 0.018004692610769698),
#  (296, 0.04654145523585096),
#  (297, 0.004735853623093905),
#  (298, 0.018004692610769698),
#  (299, 0.028536762625081268),
#  (300, 0.04654145523585096),
#  (301, 0.04654145523585096),
#  (302, 0.09308291047170192),
#  (303, 0.04654145523585096),
#  (304, 0.04654145523585096),
#  (305, 0.04654145523585096),
#  (306, 0.04654145523585096),
#  (307, 0.018004692610769698),
#  (308, 0.028536762625081268),
#  (309, 0.04654145523585096),
#  (310, 0.04654145523585096),
#  (311, 0.04654145523585096),
#  (312, 0.04654145523585096),
#  (313, 0.04654145523585096),
#  (314, 0.04654145523585096),
#  (315, 0.04654145523585096),
#  (316, 0.04654145523585096),
#  (317, 0.04654145523585096),
#  (318, 0.018004692610769698),
#  (319, 0.057073525250162536),
#  (320, 0.04654145523585096),
#  (321, 0.04654145523585096),
#  (322, 0.04654145523585096),
#  (323, 0.09308291047170192),
#  (324, 0.018004692610769698),
#  (325, 0.04654145523585096),
#  (326, 0.04654145523585096),
#  (327, 0.04654145523585096),
#  (328, 0.028536762625081268),
#  (329, 0.028536762625081268),
#  (330, 0.028536762625081268),
#  (331, 0.04654145523585096),
#  (332, 0.028536762625081268),
#  (333, 0.0856102878752438),
#  (334, 0.004735853623093905),
#  (335, 0.04654145523585096),
#  (336, 0.018004692610769698),
#  (337, 0.04654145523585096),
#  (338, 0.04654145523585096),
#  (339, 0.018004692610769698),
#  (340, 0.057073525250162536),
#  (342, 0.057073525250162536),
#  (343, 0.04654145523585096),
#  (344, 0.010532070014311565),
#  (345, 0.018004692610769698),
#  (346, 0.028536762625081268),
#  (347, 0.028536762625081268),
#  (348, 0.028536762625081268),
#  (349, 0.028536762625081268),
#  (350, 0.028536762625081268),
#  (351, 0.028536762625081268),
#  (352, 0.09308291047170192),
#  (353, 0.04654145523585096),
#  (354, 0.04654145523585096),
#  (355, 0.04654145523585096),
#  (356, 0.018004692610769698),
#  (357, 0.04654145523585096),
#  (358, 0.0315962100429347),
#  (359, 0.04654145523585096),
#  (360, 0.04654145523585096),
#  (361, 0.028536762625081268),
#  (362, 0.010532070014311565),
#  (363, 0.04654145523585096),
#  (364, 0.010532070014311565),
#  (365, 0.018004692610769698),
#  (366, 0.028536762625081268),
#  (367, 0.01894341449237562),
#  (368, 0.010532070014311565),
#  (369, 0.04654145523585096),
#  (370, 0.04654145523585096),
#  (371, 0.028536762625081268),
#  (372, 0.09308291047170192),
#  (373, 0.04654145523585096),
#  (374, 0.04654145523585096),
#  (375, 0.04654145523585096),
#  (376, 0.04654145523585096),
#  (377, 0.09308291047170192),
#  (378, 0.09308291047170192),
#  (379, 0.04654145523585096),
#  (380, 0.18616582094340384),
#  (381, 0.028536762625081268),
#  (382, 0.028536762625081268),
#  (383, 0.04654145523585096),
#  (384, 0.04654145523585096),
#  (385, 0.04654145523585096),
#  (386, 0.04654145523585096),
#  (387, 0.04654145523585096),
#  (388, 0.04654145523585096),
#  (389, 0.0540140778323091),
#  (390, 0.04654145523585096),
#  (391, 0.04654145523585096),
#  (392, 0.04654145523585096),
#  (393, 0.04654145523585096),
#  (394, 0.04654145523585096),
#  (395, 0.028536762625081268),
#  (396, 0.028536762625081268),
#  (397, 0.04654145523585096),
#  (398, 0.028536762625081268),
#  (399, 0.04654145523585096),
#  (400, 0.04654145523585096),
#  (401, 0.04654145523585096),
#  (402, 0.04654145523585096),
#  (403, 0.04654145523585096),
#  (404, 0.057073525250162536),
#  (405, 0.028536762625081268),
#  (406, 0.028536762625081268),
#  (407, 0.04654145523585096),
#  (408, 0.0315962100429347),
#  (409, 0.04654145523585096),
#  (410, 0.028536762625081268),
#  (411, 0.04654145523585096),
#  (412, 0.04654145523585096),
#  (413, 0.010532070014311565),
#  (414, 0.04654145523585096),
#  (415, 0.04654145523585096),
#  (416, 0.04654145523585096),
#  (417, 0.04654145523585096),
#  (418, 0.04654145523585096),
#  (419, 0.028536762625081268),
#  (420, 0.028536762625081268),
#  (421, 0.057073525250162536),
#  (422, 0.018004692610769698),
#  (423, 0.036009385221539396),
#  (424, 0.09308291047170192)]

# %%
# Train the lda model using gensim.models.LdaMulticore and save it to ‘lda_model’
lda_model = gensim.models.LdaMulticore(corpus, num_topics=4, id2word=dictionary, passes=10, workers=2)

lda_model.save('model1.gensim')

for idx, topic in lda_model.print_topics(-1):
    print('Topic: {} \nWords: {}'.format(idx, topic))
# Out:
# Topic: 0
# Words: 0.009*"venio" + 0.007*"carmen1" + 0.007*"puer" + 0.005*"pecus2" + 0.005*"omne" + 0.005*"facio" + 0.005*"pecus1" + 0.005*"vitula" + 0.004*"video" + 0.004*"pasco"
# Topic: 1
# Words: 0.001*"carmen1" + 0.001*"canto" + 0.001*"amor" + 0.001*"dico2" + 0.001*"venio" + 0.001*"silva" + 0.001*"grex" + 0.001*"video" + 0.001*"incipio" + 0.001*"herba"
# Topic: 2
# Words: 0.018*"carmen1" + 0.012*"canto" + 0.007*"curo" + 0.007*"silva" + 0.007*"amor" + 0.007*"cano" + 0.007*"dico2" + 0.006*"levo1" + 0.005*"fero" + 0.005*"venio"
# Topic: 3
# Words: 0.008*"grex" + 0.007*"pecus2" + 0.005*"tempus" + 0.005*"herba" + 0.005*"ovile" + 0.005*"tremulus" + 0.004*"video" + 0.004*"silva" + 0.004*"no1" + 0.004*"sum1"

# %%
# Run LDA using TF-IDF
lda_model_tfidf = gensim.models.LdaMulticore(corpus_tfidf, num_topics=4, id2word=dictionary, passes=10, workers=2)

lda_model_tfidf.save('model2.gensim')

for idx, topic in lda_model_tfidf.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))
# Out:
# Topic: 0 Word: 0.002*"levo1" + 0.001*"meroe" + 0.001*"curo" + 0.001*"vitula" + 0.001*"perdo" + 0.001*"tandem" + 0.001*"tremulus" + 0.001*"ovile" + 0.001*"poculum" + 0.001*"phyllida"
# Topic: 1 Word: 0.001*"venio" + 0.001*"facio" + 0.001*"vitula" + 0.001*"caper" + 0.001*"alter" + 0.001*"carmen1" + 0.001*"pollio" + 0.001*"pecus1" + 0.001*"pono" + 0.001*"munero"
# Topic: 2 Word: 0.002*"gallus1" + 0.001*"venio" + 0.001*"cresco" + 0.001*"vester" + 0.001*"capio" + 0.001*"laboro" + 0.001*"lycoris" + 0.001*"arcades" + 0.001*"paeniteo" + 0.001*"phyllon"
# Topic: 3 Word: 0.002*"meliboee" + 0.001*"pectus" + 0.001*"felix1" + 0.001*"do" + 0.001*"pinus" + 0.001*"benignus" + 0.001*"suadeo" + 0.001*"liquor2" + 0.001*"carpo" + 0.001*"patior"

# %%
# Test an unseen document against the lda models. This is one of Boccaccio's bucolic poems, so it should have a high score.

unseen_document1 = open('/home/sjhuskey/Dropbox/What-is-digital-latin/test_texts/boccaccio1.txt')
unseen_text1 = unseen_document1.read()
bow_vector = dictionary.doc2bow(prepare_text(unseen_text1))

for index, score in sorted(lda_model[bow_vector], key=lambda tup: -1*tup[1]):
    print("LDA Score: {}\t Topic: {}".format(score, lda_model.print_topic(index, 5)))
    
for index, score in sorted(lda_model_tfidf[bow_vector], key=lambda tup: -1*tup[1]):
    print("\nTF-IDF Score: {}\t \nTopic: {}".format(score, lda_model_tfidf.print_topic(index, 5)))
# Out:
# LDA Score: 0.6724274754524231	 Topic: 0.018*"carmen1" + 0.012*"canto" + 0.007*"curo" + 0.007*"silva" + 0.007*"amor"
# LDA Score: 0.16603590548038483	 Topic: 0.008*"grex" + 0.007*"pecus2" + 0.005*"tempus" + 0.005*"herba" + 0.005*"ovile"
# LDA Score: 0.1608441174030304	 Topic: 0.009*"venio" + 0.007*"carmen1" + 0.007*"puer" + 0.005*"pecus2" + 0.005*"omne"
#
# TF-IDF Score: 0.7392052412033081
# Topic: 0.002*"levo1" + 0.001*"meroe" + 0.001*"curo" + 0.001*"vitula" + 0.001*"perdo"
#
# TF-IDF Score: 0.25934189558029175
# Topic: 0.002*"gallus1" + 0.001*"venio" + 0.001*"cresco" + 0.001*"vester" + 0.001*"capio"

# %%
# Test an unseen document against the lda models. This is another one of Boccaccio's bucolic poems, so it should have a high score.

unseen_document2 = open('/home/sjhuskey/Dropbox/What-is-digital-latin/test_texts/boccaccio2.txt')
unseen_text2 = unseen_document2.read()
bow_vector = dictionary.doc2bow(prepare_text(unseen_text2))

for index, score in sorted(lda_model[bow_vector], key=lambda tup: -1*tup[1]):
    print("LDA Score: {}\t Topic: {}".format(score, lda_model.print_topic(index, 5)))
    
for index, score in sorted(lda_model_tfidf[bow_vector], key=lambda tup: -1*tup[1]):
    print("\nTF-IDF Score: {}\t \nTopic: {}".format(score, lda_model_tfidf.print_topic(index, 5)))
# Out:
# LDA Score: 0.6933873891830444	 Topic: 0.018*"carmen1" + 0.012*"canto" + 0.007*"curo" + 0.007*"silva" + 0.007*"amor"
# LDA Score: 0.165932759642601	 Topic: 0.009*"venio" + 0.007*"carmen1" + 0.007*"puer" + 0.005*"pecus2" + 0.005*"omne"
# LDA Score: 0.14000031352043152	 Topic: 0.008*"grex" + 0.007*"pecus2" + 0.005*"tempus" + 0.005*"herba" + 0.005*"ovile"
#
# TF-IDF Score: 0.8080786466598511
# Topic: 0.002*"levo1" + 0.001*"meroe" + 0.001*"curo" + 0.001*"vitula" + 0.001*"perdo"
#
# TF-IDF Score: 0.19049717485904694
# Topic: 0.002*"gallus1" + 0.001*"venio" + 0.001*"cresco" + 0.001*"vester" + 0.001*"capio"

# %%
# Test another unseen document against the lda models. This is a letter by Boccaccio, so it shouldn't have a high score.

unseen_document3 = open('/home/sjhuskey/Dropbox/What-is-digital-latin/test_texts/boccaccioEp1.txt')
unseen_text3 = unseen_document3.read()
bow_vector = dictionary.doc2bow(prepare_text(unseen_text3))

for index, score in sorted(lda_model[bow_vector], key=lambda tup: -1*tup[1]):
    print("LDA Score: {}\t Topic: {}".format(score, lda_model.print_topic(index, 5)))
    
for index, score in sorted(lda_model_tfidf[bow_vector], key=lambda tup: -1*tup[1]):
    print("\nTF-IDF Score: {}\t \nTopic: {}".format(score, lda_model_tfidf.print_topic(index, 5)))
# Out:
# LDA Score: 0.7241349816322327	 Topic: 0.018*"carmen1" + 0.012*"canto" + 0.007*"curo" + 0.007*"silva" + 0.007*"amor"
# LDA Score: 0.2666381299495697	 Topic: 0.009*"venio" + 0.007*"carmen1" + 0.007*"puer" + 0.005*"pecus2" + 0.005*"omne"
#
# TF-IDF Score: 0.5357410311698914
# Topic: 0.002*"gallus1" + 0.001*"venio" + 0.001*"cresco" + 0.001*"vester" + 0.001*"capio"
#
# TF-IDF Score: 0.4554351270198822
# Topic: 0.002*"levo1" + 0.001*"meroe" + 0.001*"curo" + 0.001*"vitula" + 0.001*"perdo"

# %%
# Test another unseen document against the lda models. This is a theological text.

unseen_document4 = open('/home/sjhuskey/Dropbox/What-is-digital-latin/test_texts/lactantius.txt')
unseen_text4 = unseen_document4.read()
bow_vector = dictionary.doc2bow(prepare_text(unseen_text4))

for index, score in sorted(lda_model[bow_vector], key=lambda tup: -1*tup[1]):
    print("LDA Score: {}\t Topic: {}".format(score, lda_model.print_topic(index, 5)))
    
for index, score in sorted(lda_model_tfidf[bow_vector], key=lambda tup: -1*tup[1]):
    print("\nTF-IDF Score: {}\t \nTopic: {}".format(score, lda_model_tfidf.print_topic(index, 5)))
# Out:
# LDA Score: 0.6372178196907043	 Topic: 0.018*"carmen1" + 0.012*"canto" + 0.007*"curo" + 0.007*"silva" + 0.007*"amor"
# LDA Score: 0.22623443603515625	 Topic: 0.009*"venio" + 0.007*"carmen1" + 0.007*"puer" + 0.005*"pecus2" + 0.005*"omne"
# LDA Score: 0.1364828199148178	 Topic: 0.008*"grex" + 0.007*"pecus2" + 0.005*"tempus" + 0.005*"herba" + 0.005*"ovile"
#
# TF-IDF Score: 0.6848052740097046
# Topic: 0.002*"levo1" + 0.001*"meroe" + 0.001*"curo" + 0.001*"vitula" + 0.001*"perdo"
#
# TF-IDF Score: 0.3150583505630493
# Topic: 0.002*"gallus1" + 0.001*"venio" + 0.001*"cresco" + 0.001*"vester" + 0.001*"capio"

# %%
# Test a short passage against the lda models. This is passage from Caesar's commentary on the civil war.

unseen_text5 = '''Litteris C. Caesaris consulibus redditis aegre ab his impetratum est summa tribunorum plebis contentione, ut in senatu recitarentur; ut vero ex litteris ad senatum referretur, impetrari non potuit. Referunt consules de re publica [in civitate]. [Incitat] L. Lentulus consul senatu rei publicae se non defuturum pollicetur, si audacter ac fortiter sententias dicere velint; sin Caesarem respiciant atque eius gratiam sequantur, ut superioribus fecerint temporibus, se sibi consilium capturum neque senatus auctoritati obtemperaturum: habere se quoque ad Caesaris gratiam atque amicitiam receptum.'''
bow_vector = dictionary.doc2bow(prepare_text(unseen_text5))

for index, score in sorted(lda_model[bow_vector], key=lambda tup: -1*tup[1]):
    print("LDA Score: {}\t Topic: {}".format(score, lda_model.print_topic(index, 5)))
    
for index, score in sorted(lda_model_tfidf[bow_vector], key=lambda tup: -1*tup[1]):
    print("\nTF-IDF Score: {}\t \nTopic: {}".format(score, lda_model_tfidf.print_topic(index, 5)))
# Out:
# LDA Score: 0.7339155673980713	 Topic: 0.018*"carmen1" + 0.012*"canto" + 0.007*"curo" + 0.007*"silva" + 0.007*"amor"
# LDA Score: 0.1444583684206009	 Topic: 0.009*"venio" + 0.007*"carmen1" + 0.007*"puer" + 0.005*"pecus2" + 0.005*"omne"
# LDA Score: 0.10685240477323532	 Topic: 0.008*"grex" + 0.007*"pecus2" + 0.005*"tempus" + 0.005*"herba" + 0.005*"ovile"
# LDA Score: 0.014773598872125149	 Topic: 0.001*"carmen1" + 0.001*"canto" + 0.001*"amor" + 0.001*"dico2" + 0.001*"venio"
#
# TF-IDF Score: 0.8613746166229248
# Topic: 0.002*"levo1" + 0.001*"meroe" + 0.001*"curo" + 0.001*"vitula" + 0.001*"perdo"
#
# TF-IDF Score: 0.10730376839637756
# Topic: 0.002*"gallus1" + 0.001*"venio" + 0.001*"cresco" + 0.001*"vester" + 0.001*"capio"
#
# TF-IDF Score: 0.0158771313726902
# Topic: 0.002*"meliboee" + 0.001*"pectus" + 0.001*"felix1" + 0.001*"do" + 0.001*"pinus"
#
# TF-IDF Score: 0.015444422140717506
# Topic: 0.001*"venio" + 0.001*"facio" + 0.001*"vitula" + 0.001*"caper" + 0.001*"alter"

# %%
# Visualize topics.
dictionary = gensim.corpora.Dictionary.load('dictionary.gensim')
corpus = pickle.load(open('corpus.pkl', 'rb'))
lda = gensim.models.ldamodel.LdaModel.load('model1.gensim')

import pyLDAvis.gensim
lda_display = pyLDAvis.gensim.prepare(lda, corpus, dictionary, sort_topics=False)
pyLDAvis.display(lda_display)

# Saliency: a measure of how much the term tells you about the topic.

# Relevance: a weighted average of the probability of the word given the topic and the word given the topic normalized by the probability of the topic.

# The size of the bubble measures the importance of the topics, relative to the data.
# Out:
# /home/sjhuskey/anaconda3/envs/cltk/lib/python3.7/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el216251399176973378886317020125"></div>
# <script type="text/javascript">
#
# var ldavis_el216251399176973378886317020125_data = {"mdsDat": {"x": [0.04546712682366796, -0.005770591174661946, 0.07745190720366099, -0.11714844285266687], "y": [-0.09553656353367954, 0.004564865468694653, 0.07722138110489842, 0.013750316960086498], "topics": [1, 2, 3, 4], "cluster": [1, 1, 1, 1], "Freq": [19.12320327758789, 0.06299711018800735, 58.12221908569336, 22.691587448120117]}, "tinfo": {"Category": ["Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4"], "Freq": [28.0, 11.0, 10.0, 17.0, 9.0, 5.0, 8.0, 8.0, 9.0, 6.0, 4.0, 6.0, 3.0, 10.0, 2.0, 5.0, 3.0, 3.0, 5.0, 9.0, 4.0, 4.0, 4.0, 7.0, 6.0, 6.0, 6.0, 6.0, 4.0, 3.0, 2.4883177280426025, 1.9029592275619507, 1.903221845626831, 1.9029147624969482, 1.902630090713501, 1.9022077322006226, 1.3178479671478271, 1.3177467584609985, 1.3175570964813232, 1.317649483680725, 1.3176482915878296, 1.317541480064392, 1.3175665140151978, 1.3175044059753418, 1.3173748254776, 1.3172528743743896, 1.31722092628479, 1.3173179626464844, 1.3172852993011475, 1.3172060251235962, 1.3170980215072632, 1.316978931427002, 1.3169224262237549, 2.4885313510894775, 0. ...

# %%
# Visualize topics.
dictionary = gensim.corpora.Dictionary.load('dictionary.gensim')
corpus = pickle.load(open('corpus.pkl', 'rb'))
lda = gensim.models.ldamodel.LdaModel.load('model2.gensim')

import pyLDAvis.gensim
lda_display = pyLDAvis.gensim.prepare(lda, corpus, dictionary, sort_topics=False)
pyLDAvis.display(lda_display)

# Saliency: a measure of how much the term tells you about the topic.

# Relevance: a weighted average of the probability of the word given the topic and the word given the topic normalized by the probability of the topic.

# The size of the bubble measures the importance of the topics, relative to the data.
# Out:
# /home/sjhuskey/anaconda3/envs/cltk/lib/python3.7/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el73051399991493579608055353835"></div>
# <script type="text/javascript">
#
# var ldavis_el73051399991493579608055353835_data = {"mdsDat": {"x": [-0.0002568526188861883, 0.003571588936596515, -0.0032249492934159894, -8.978702429433553e-05], "y": [0.0, 0.0, 0.0, 0.0], "topics": [1, 2, 3, 4], "cluster": [1, 1, 1, 1], "Freq": [0.05227470397949219, 73.40630340576172, 26.489084243774414, 0.05233713239431381]}, "tinfo": {"Category": ["Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4"], "Freq": [6.0, 5.0, 5.0, 5.0, 5.0, 5.0, 4.0, 4.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 0.001345256925560534, 0.001345256925560534, 0.001345256925560534, 0.001345256925560534, 0.001345256925560534, 0.001345256925560534, 0.001345256925560534, 0.001345256925560534, 0.0013454679865390062, 0.0013454880099743605, 0.0013457261957228184, 0.0013456345768645406, 0.001345586497336626, 0.0013455653097480536, 0.0013455492444336414, 0.001345600700005889, 0.0013456084998324513, 0.0013456003507599235, 0.0013455954613164067, 0.0013455585576593876, 0.0013456020969897509, 0.0013455768348649144, 0.0013455700827762485, 0.0013456001179292798, 0.0013455648440867662, 0.0013455883599817753, 0.0013455135049298406, 0.0013455285225063562, 0.0013455323642119765, 0.0013455429580062628, 0.0013456613523885608, 0.0013455678708851337, 0.0013456039596349, 0.0013455816078931093, 0.0013456359738484025, 0.001345595344901085, 0.00134560267906636, 0.0013456096639856696, 0.001345609431155026, 0.0013456102460622787, 0.0013456050073727965,  ...
